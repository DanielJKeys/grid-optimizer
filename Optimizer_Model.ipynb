# %% [markdown]
# # **Optimizer Model:** Generates models for triangulaton of a grid using spheres and cones.

# %% [markdown]
# # Model Variables

# %% [markdown]
# **BEFORE RUNNING THE MODEL:** Add a folder to the drive that has the corresponding grid size in the format: Model_Results_X3_Y3_Z3.  Results will not be saved if folder does not exist!

# %%
# Grid size
# Use this variable to set the size of the grid of points
x, y, z = [3,3,3]

# Resolution: Number of points per unit
# Setting this allows for more precise models.  Value has to be >= 1
# Increasing this variable by one increases runtime by roughly time^1.6
res = 1

# Iterations of models
# Not a smart shutoff, the more iterations, the more accurate the model.
iterate = 5000

# Enter the radii and heights of the shapes
sphere_radii = [3,4]

# For example of this, see the "Cone Model Example.png"
# Note that the first value of the radius and heights pair together. They don't both get randomly selected.
cone_radii = [3,4]
cone_heights = [3,4]

# "Save All Models? (Y/N)  *This dramatically increases runtime!*
is_save = False

# Multiple Sensor Types? (Y/N)
# Red only requires one sensor to triagulate, Bule requires 3
sensors = "BR"
# Blue only: sensors = "B"
# Red only: sensor = "R"

# Special Grid? (Y/N)
special_grid = False

# Minimum Shapes (S), Minimum Cost (C), Optimal Shapes (X), Optimal Cost (O)?
# Minimum: Shotgun approach, sprays models to approximate the most accurate
# Optimal: "Smart" approach, attempts to place the "Best" shape each time.
minimize = 'C'

# Filepath of this script
drive_path = "/content/drive/Shareddrives/Prime TTT (IL4)/DevOps/Models/Grid Optimizer Model/"

# %%
def sphere_cost(factor, type="B"):
    if type == "B":
        return volume_sphere(factor)
    else:
        return volume_sphere(factor) * 3

# %%
def cone_cost(factor_1, factor_2, type="B"):
    if type == "B":
        return volume_cone(factor_1, factor_2)
    else:
        return volume_cone(factor_1, factor_2) * 3

# %% [markdown]
# **Settings and Variables for Graphing**

# %%
# Default Resolution of spheres graphed.  Recommend = 5 for testing, 80 for high quality outputs
RESOLUTION = 10
# Default Resolution of spheres graphed.  Number from 0 to 1
DEFAULT_OPACITY = .3
# Captures the graph-able data
fig_data = []
# Captures the data from the shapes that need graphed
shape_data = []

# %% [markdown]
# **Imports**

# %%
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import os
import tkinter.filedialog as fd
import math
import random
from operator import itemgetter
from google.colab import drive
drive.mount('/content/drive')

is_spheres = False
if sphere_radii:
  is_spheres = True

is_cones = False
if cone_radii:
  is_cones = True
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Functions

# %%
def distance_finder(x1, y1, z1, x2, y2, z2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2 + (z1 - z2) ** 2)

# %%
def is_Intersect(x1, y1, z1, r1, x2, y2, z2, r2):
    if distance_finder(x1, y1, z1, x2, y2, z2) > r1 + r2:
        return False
    return True

# %%
def plotly_sphere(x, y, z, radius, resolution=RESOLUTION):
    u, v = np.mgrid[0:2 * np.pi:resolution * 2j, 0:np.pi:resolution * 1j]
    X = radius * np.cos(u) * np.sin(v) + x
    Y = radius * np.sin(u) * np.sin(v) + y
    Z = radius * np.cos(v) + z
    return X, Y, Z

# %%
def volume_cone(r, h):
    return (2 / 3) * math.pi * r ** 3 + r ** 2 * ((h * math.pi) / 3)

# %%
def volume_sphere(r):
    return (4 / 3) * math.pi * r ** 3

# %%
def rotate(xy, theta):
    cos_theta, sin_theta = math.cos(theta), math.sin(theta)

    return (
        xy[0] * cos_theta - xy[1] * sin_theta,
        xy[0] * sin_theta + xy[1] * cos_theta
    )

# %%
def translate(xy, offset):
    return xy[0] + offset[0], xy[1] + offset[1]

# %% [markdown]
# #Classes

# %% [markdown]
# **Neural Network Class**

# %%
class NN:
    def __init__(self, grid_x, grid_y, grid_z, resolution, stypes="B", sphere_radii=None, cone_radii=None,
                 cone_heights=None, special_grid=False):
        self.g_x = grid_x
        self.g_y = grid_y
        self.g_z = grid_z
        self.res = resolution
        self.Models = []
        self.sphere_radii = sphere_radii
        self.cone_radii = cone_radii
        self.cone_heights = cone_heights
        self.stypes = stypes
        self.special_grid = special_grid

        if sphere_radii is not None:
            if cone_heights is not None:
                self.shape = 'SC'
            else:
                self.shape = 'S'
        else:
            self.shape = 'C'
        return

    # Print all the models stored in the network
    def print(self):
        for i, m in enumerate(self.Models):
            print(f"Model {i}:")
            m.print()

    # Run the network to find the minimum # spheres to triangulate the grid and return the best model
    def run_minimize_nodes(self, iterations, min_shapes=999999, save_all=False):
        ideal_model = None
        for i in range(0, iterations):
            m = Model(self.g_x, self.g_y, self.g_z, self.res, special_grid=self.special_grid)
            c = 0
            goal = False

            while not (goal or (c >= min_shapes and not save_all)):
                c = c + 1

                rand_shape = random.choice(self.shape)
                if rand_shape == 'C':
                    rand_sensor = random.choice(self.stypes)
                    select = random.randrange(0, len(self.cone_radii), step=1)
                    if self.special_grid:
                        m.Cones.append(
                            m.add_cone_restricted(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                    else:
                        m.Cones.append(m.add_cone(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                    goal = m.goal_last_cone_polar()
                else:
                    rand_sensor = random.choice(self.stypes)
                    radius_select = random.randrange(0, len(self.sphere_radii), step=1)
                    if self.special_grid:
                        m.Spheres.append(m.add_sphere_restricted(self.sphere_radii[radius_select], type=rand_sensor))
                    else:
                        m.Spheres.append(m.add_sphere(self.sphere_radii[radius_select], type=rand_sensor))
                    goal = m.goal_last_sphere()

            print(f"Iteration {i} Number of M Shapes:{m.num_shapes()}")

            if save_all:
                m.save()

            if c < min_shapes:
                min_shapes = c
                print(f"Minimum Shapes: {min_shapes}")
                m.save()
                ideal_model = m

        # Prints the ideal model
        print(f"Spheres: {len(ideal_model.Spheres)}")
        print(f"Cones: {len(ideal_model.Cones)}")
        ideal_model.print()
        ideal_model.graph()

    def run_optimal_nodes(self, iterations, min_shapes=999999, save_all=False):
        ideal_model = None
        for i in range(0, iterations):
            m = Model(self.g_x, self.g_y, self.g_z, self.res, special_grid=self.special_grid)
            c = 0
            goal = False

            while not (goal or (c >= min_shapes and not save_all)):

                c = c + 1

                rand_shape = random.choice(self.shape)
                if rand_shape == 'C':
                    rand_sensor = random.choice(self.stypes)
                    select = random.randrange(0, len(self.cone_radii), step=1)
                    m.Cones.append(
                        m.add_best_cone(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                    goal = m.goal_last_cone_polar()
                else:
                    rand_sensor = random.choice(self.stypes)
                    radius_select = random.randrange(0, len(self.sphere_radii), step=1)
                    m.Spheres.append(m.add_best_sphere(self.sphere_radii[radius_select], type=rand_sensor))
                    goal = m.goal_last_sphere()

            print(f"Iteration {i} Number of M Shapes:{m.num_shapes()}")

            if save_all:
                m.save()

            if c < min_shapes:
                min_shapes = c
                print(f"Minimum Shapes: {min_shapes}")
                m.save()
                ideal_model = m

        # Prints the ideal model
        print(f"Spheres: {len(ideal_model.Spheres)}")
        print(f"Cones: {len(ideal_model.Cones)}")
        ideal_model.print()
        ideal_model.graph()

    # Runs the model, aiming to reduce the cost of the system
    def run_minimize_cost(self, iterations, min_cost=99999999999999, save_all=False):
        ideal_model = None
        for i in range(0, iterations):
            m = Model(self.g_x, self.g_y, self.g_z, self.res, special_grid=self.special_grid)
            goal = False
            cost = 0

            while not (goal or (cost >= min_cost and not save_all)):
              rand_shape = random.choice(self.shape)
              if rand_shape == 'C':
                  rand_sensor = random.choice(self.stypes)
                  select = random.randrange(0, len(self.cone_radii), step=1)
                  cost = cost + cone_cost(self.cone_radii[select], self.cone_heights[select], rand_sensor)
                  if special_grid:
                    m.Cones.append(m.add_cone_restricted(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                  else:
                    m.Cones.append(m.add_cone(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                  goal = m.goal_last_cone_polar()
              elif rand_shape == 'S':
                  rand_sensor = random.choice(self.stypes)
                  radius_select = random.randrange(0, len(self.sphere_radii), step=1)
                  cost = cost + sphere_cost(self.sphere_radii[radius_select], rand_sensor)
                  if special_grid:
                    m.Spheres.append(m.add_sphere_restricted(self.sphere_radii[radius_select], type=rand_sensor))
                  else:
                    m.Spheres.append(m.add_sphere(self.sphere_radii[radius_select], type=rand_sensor))
                  goal = m.goal_last_sphere()

            print(f"Iteration {i} Number of M Shapes:{m.num_shapes()}")

            if save_all:
                m.save()

            if cost < min_cost:
                min_cost = cost
                print(f"Minimum Cost: {min_cost}")
                m.save()
                ideal_model = m

        # Prints the ideal model
        print(f"Spheres: {len(ideal_model.Spheres)}")
        print(f"Cones: {len(ideal_model.Cones)}")
        ideal_model.print()
        ideal_model.graph()
        return

    def run_optimal_cost(self, iterations, min_cost=99999999999999, save_all=False):
        ideal_model = None
        for i in range(0, iterations):
            m = Model(self.g_x, self.g_y, self.g_z, self.res, special_grid=self.special_grid)
            goal = False
            cost = 0

            while not (goal or (cost >= min_cost and not save_all)):
                rand_shape = random.choice(self.shape)

                if rand_shape == 'C':
                    rand_sensor = random.choice(self.stypes)
                    select = random.randrange(0, len(self.cone_radii), step=1)
                    cost = cost + cone_cost(self.cone_radii[select], self.cone_heights[select], rand_sensor)
                    m.Cones.append(
                        m.add_best_cone(self.cone_radii[select], self.cone_heights[select], type=rand_sensor))
                    goal = m.goal_last_cone_polar()

                elif rand_shape == 'S':
                    rand_sensor = random.choice(self.stypes)
                    radius_select = random.randrange(0, len(self.sphere_radii), step=1)
                    cost = cost + sphere_cost(self.sphere_radii[radius_select], rand_sensor)
                    m.Spheres.append(m.add_best_sphere(self.sphere_radii[radius_select], type=rand_sensor))
                    goal = m.goal_last_sphere()

            print(f"Iteration {i} Number of M Shapes:{m.num_shapes()}")

            if save_all:
                m.save()

            if cost < min_cost:
                min_cost = cost
                print(f"Minimum Cost: {min_cost}")
                m.save()
                ideal_model = m

        # Prints the ideal model
        print(f"Spheres: {len(ideal_model.Spheres)}")
        print(f"Cones: {len(ideal_model.Cones)}")
        ideal_model.print()
        ideal_model.graph()
        return

# %% [markdown]
# **Instance of Model**

# %%
class Model:
    def __init__(self, grid_x, grid_y, grid_z, grid_res, stypes="B", special_grid=False):
        self.Spheres = []
        self.Cones = []
        self.Points = []
        self.res = grid_res
        self.stypes = stypes
        self.special_grid = special_grid
        if not special_grid:
            self.x = grid_x
            self.y = grid_y
            self.z = grid_z

            self.Rects = [
                Rect(start_x=0, len_x=self.x, start_y=0, len_y=self.y, start_z=0, len_z=self.z, rotate_degrees=0)
            ]

        else:
            self.Rects = [
                Rect(start_x=0, len_x=30, start_y=86, len_y=200, start_z=0, len_z=30, rotate_degrees=0),
                Rect(start_x=0, len_x=30, start_y=286, len_y=100, start_z=0, len_z=30, rotate_degrees=30),
                Rect(start_x=0, len_x=30, start_y=0, len_y=100, start_z=0, len_z=30, rotate_degrees=-30)
            ]

            self.x = 90
            self.y = 400
            self.z = 30

        self.grid_generation()
        return

    def grid_generation_rotate_rect(self, degree, len_x, len_y, len_z, y_start=0, x_start=0, z_start=0, rotate="C",
                                    res=1):
        a = math.cos(math.radians(degree))
        b = math.sin(math.radians(degree))

        if rotate == "C":
            for x in np.linspace(0, len_x, (res * len_x) + 1):
                for y in np.linspace(0, len_y, (res * len_y) + 1):
                    y_actual = y_start + y * b + (len_x - x) * a
                    x_actual = x_start + y * a
                    for z in np.linspace(0, len_z, (res * len_z) + 1):
                        self.Points.append([round(x_actual, 3), round(y_actual, 3), z + z_start, 0])
        else:
            for x in np.linspace(0, len_x, (res * len_x) + 1):
                for y in np.linspace(0, len_y, (res * len_y) + 1):
                    y_actual = y_start + (len_y - y) * b + x * a
                    x_actual = x_start + (len_x - x) + y * a
                    for z in np.linspace(0, len_z, (res * len_z) + 1):
                        self.Points.append([round(x_actual, 3), round(y_actual), z + z_start, 0])

    def grid_generation(self):
        data = []
        for rect in self.Rects:
          if rect.deg == 0:
            self.grid_generation_rect(grid_x=rect.l_x, grid_y=rect.l_y, grid_z=rect.l_z, start_x=rect.s_x,
                                          start_y=rect.s_y, start_z=rect.s_x, res=self.res)
          if rect.deg > 0:
            self.grid_generation_rotate_rect(degree=rect.deg, len_x=rect.l_x, len_y=rect.l_y, len_z=rect.l_z,
                                                 x_start=rect.s_x, y_start=rect.s_y, z_start=rect.s_z, rotate="C",
                                                 res=self.res)

          if rect.deg < 0:
            self.grid_generation_rotate_rect(degree=abs(rect.deg), len_x=rect.l_x, len_y=rect.l_y, len_z=rect.l_z,
                                                 x_start=rect.s_x, y_start=rect.s_y, z_start=rect.s_z, rotate="CC",
                                                 res=self.res)
          data.append(rect.graph())
        return

    def grid_generation_rect(self, grid_x, grid_y, grid_z, res=1, start_x=0, start_y=0, start_z=0):
        for x in np.linspace(0, grid_x, (res * grid_x) + 1):
            for y in np.linspace(0, grid_y, (res * grid_y) + 1):
                for z in np.linspace(0, grid_z, (res * grid_z) + 1):
                    self.Points.append([x + start_x, y + start_y, z + start_z, 0])
        return

    # Saves the Model's Spheres and Parameters
    def save(self):
        total_cost = 0
        for sphere in self.Spheres:
            total_cost = total_cost + sphere_cost(sphere.r)
        for cone in self.Cones:
            total_cost = total_cost + cone_cost(cone.r, cone.h)

        data = []
        data_headers = ["X","Y","Z","Radius","Height","Cost","Volume","Shape","Type","X2","Y2","Z2","Degrees"]

        for sphere in self.Spheres:
          data.append(sphere.save())
        for cone in self.Cones:
          data.append(cone.save())

        df = pd.DataFrame(columns=data_headers,data=data)
        df.to_csv(drive_path + f"Model_Save_X{self.x}_Y{self.y}_Z{self.z}/Model_Save_X{self.x}_Y{self.y}_Z{self.z}_Res{self.res}_Cost_{round(sum(df['Cost']))}.csv")
        return

    # Prints the model's Spheres
    def print(self):
        for i, s in enumerate(self.Spheres):
            print(f"Sphere {i}:")
            s.print()
        for i, c in enumerate(self.Cones):
            print(f"Cone {i}:")
            c.print()

    # Returns the number of Spheres in a model
    def num_shapes(self):
        return len(self.Spheres) + len(self.Cones)

    # Checks the last sphere if it overlaps any of the grid's points, and updates accordingly
    def goal_last_sphere(self):
        goal = True
        for point in self.Points:
            if point[3] < 3:
              if distance_finder(self.Spheres[-1].x, self.Spheres[-1].y, self.Spheres[-1].z, point[0], point[1], point[2]) <= self.Spheres[-1].r:
                if self.Spheres[-1].t == "B":
                  point[3] = point[3] + 1
                else:
                  point[3] = point[3] + 3
                if point[3] < 3:
                  goal = False
              else:
                if point[3] < 3:
                  goal = False
        return goal

    def goal_last_cone_polar(self):
        # Initialize the Cone
        O = np.array((self.Cones[-1].x, self.Cones[-1].y, self.Cones[-1].z))  # coordinate of the origin
        T = np.array((self.Cones[-1].tip_x, self.Cones[-1].tip_y, self.Cones[-1].tip_z))  # coordinate of the tip

        # Find the height of the cone
        H = np.linalg.norm(O - T)

        # Define a unit vector that points from T to O
        h = (O - T) / H

        # Find the "side" of the cone
        S = math.sqrt(H ** 2 + self.Cones[-1].r ** 2)

        # Find the half cone angle
        alpha = math.atan2(self.Cones[-1].r, H)

        goal = True

        for point in self.Points:
            if point[3] < 3:
                P = np.array((point[0], point[1], point[2]))

                # In order for P be inside the cone, it must satisfy the following two conditions:
                # 1. |TP| <= S
                # 2. Angle between <TP> and <TO> <= alpha

                # Check condition 1
                TP = np.linalg.norm(P - T)
                if TP <= S:
                    # Check condition 2
                    if math.acos(round(np.dot((P - T), h) / TP, 6)) <= alpha:
                        if self.Cones[-1].t == "B":
                            point[3] = point[3] + 1
                        else:
                            point[3] = point[3] + 3

                if point[3] < 3:
                    goal = False
        return goal

    # Graph the model
    def graph(self):
        data = []

        # Spheres graphing
        for sphere in self.Spheres:
            data.append(sphere.graph())

        # Cone graphing
        for cone in self.Cones:
            data.append(cone.graph_cone())
            data.append(cone.graph_sphere())

        # Grid of coverage defined by initial parameters
        for rect in self.Rects:
            data.append(rect.graph())


        fig = go.Figure(data=data)

        fig.update_traces(showscale=False)
        fig.update_layout(
          showlegend=False,
          autosize=False,
          width=1500,
          height=1000,
          paper_bgcolor="LightSteelBlue",
        )
        fig.show()
        return

    # Add a cone with a radius to the model
    def add_cone(self, radius, height, type="B"):
        is_repeat = True
        x_seed = 0
        y_seed = 0
        z_seed = 0

        r_seed = int(radius / 2) * self.res

        counter = 0

        while is_repeat and counter < 1000:
            counter = counter + 1
            x_seed = (random.randrange(start=0, stop=(self.x + r_seed) * self.res, step=1)) / self.res
            y_seed = (random.randrange(start=0, stop=(self.y + r_seed) * self.res, step=1)) / self.res
            z_seed = (random.randrange(start=0, stop=(self.z + r_seed) * self.res, step=1)) / self.res

            if self.num_shapes() == 0:
                is_repeat = False

            for sphere in self.Spheres:
                if sphere.x != x_seed and sphere.y != y_seed and sphere.z != z_seed:
                    is_repeat = False

            for cone in self.Cones:
                if cone.x != x_seed and cone.y != y_seed and cone.z != z_seed:
                    is_repeat = False

        (X, Y, Z) = plotly_sphere(x_seed, y_seed, z_seed, height)

        select = random.randrange(0, len(X), step=1)
        select_2 = random.randrange(0, len(X[select]), step=1)

        return Cone(x_seed, y_seed, z_seed, radius, height, X[select][select_2], Y[select][select_2],
                    Z[select][select_2], type=type)

    # Add a sphere with a radius to the model
    def add_sphere(self, radius, type="B"):
        is_repeat = True
        x_seed = 0
        y_seed = 0
        z_seed = 0

        r_seed = int(radius / 2) * self.res

        counter = 0

        while is_repeat and counter < 1000:
            counter = counter + 1
            x_seed = (random.randrange(start=0 - r_seed, stop=(self.x + r_seed) * self.res, step=1)) / self.res
            y_seed = (random.randrange(start=0 - r_seed, stop=(self.y + r_seed) * self.res, step=1)) / self.res
            z_seed = (random.randrange(start=0 - r_seed, stop=(self.z + r_seed) * self.res, step=1)) / self.res

            if self.num_shapes() == 0:
                is_repeat = False

            for sphere in self.Spheres:
                if sphere.x != x_seed and sphere.y != y_seed and sphere.z != z_seed:
                    is_repeat = False

            for cone in self.Cones:
                if cone.x != x_seed and cone.y != y_seed and cone.z != z_seed:
                    is_repeat = False

        return Sphere(x_seed, y_seed, z_seed, radius, type=type)

    def add_cone_restricted(self, radius, height, type="B"):
        is_repeat = True
        x_seed = 0
        y_seed = 0
        z_seed = 0

        while is_repeat:
            y_seed = random.randrange(start=0, stop=self.y, step=1) / self.res
            z_seed = random.randrange(start=0, stop=self.z, step=1) / self.res

            if y_seed > 100:
                if y_seed > 300:
                    x_seed = random.randrange(start=int(15 + math.tan(math.radians(30)) * (y_seed - 300)), stop=self.x,
                                              step=1) / self.res
                else:
                    x_seed = random.randrange(start=15, stop=self.x, step=1) / self.res
            else:
                x_seed = random.randrange(start=int(15 + math.tan(math.radians(30)) * (100 - y_seed)), stop=self.x,
                                          step=1) / self.res

            if self.num_shapes() == 0:
                is_repeat = False

            for sphere in self.Spheres:
                if sphere.x != x_seed and sphere.y != y_seed and sphere.z != z_seed:
                    is_repeat = False

            for cone in self.Cones:
                if cone.x != x_seed and cone.y != y_seed and cone.z != z_seed:
                    is_repeat = False

        (X, Y, Z) = plotly_sphere(x_seed, y_seed, z_seed, height)

        select = random.randrange(0, len(X), step=1)
        select_2 = random.randrange(0, len(X[select]), step=1)

        return Cone(x_seed, y_seed, z_seed, radius, height, X[select][select_2], Y[select][select_2],
                    Z[select][select_2], type=type)

    def add_sphere_restricted(self, radius, type="B"):
        is_repeat = True
        x_seed = 0
        y_seed = 0
        z_seed = 0

        while is_repeat:
            y_seed = random.randrange(start=0, stop=self.y, step=1) / self.res
            z_seed = random.randrange(start=0, stop=self.z, step=1) / self.res

            if y_seed > 100:
                if y_seed > 300:

                    x_seed = random.randrange(start=int(15 + math.tan(math.radians(30)) * (y_seed - 300)), stop=self.x,
                                              step=1) / self.res
                else:
                    x_seed = random.randrange(start=15, stop=self.x, step=1) / self.res
            else:

                x_seed = random.randrange(start=int(15 + math.tan(math.radians(30)) * (100 - y_seed)), stop=self.x,
                                          step=1) / self.res

            if self.num_shapes() == 0:
                is_repeat = False

            for sphere in self.Spheres:
                if sphere.x != x_seed and sphere.y != y_seed and sphere.z != z_seed:
                    is_repeat = False

            for cone in self.Cones:
                if cone.x != x_seed and cone.y != y_seed and cone.z != z_seed:
                    is_repeat = False

        return Sphere(x_seed, y_seed, z_seed, radius, type=type)

    def add_best_cone(self, radius, height, type="B", iterations=500):
        best_cone = []
        max_num_points = 0

        for i in range(0, iterations):
            cone = self.add_cone(radius, height)

            num_points = 0

            # Initialize the Cone
            O = np.array((cone.x, cone.y, cone.z))  # coordinate of the origin
            T = np.array((cone.tip_x, cone.tip_y, cone.tip_z))  # coordinate of the tip

            # Find the height of the cone
            H = np.linalg.norm(O - T)

            # Define a unit vector that points from T to O
            h = (O - T) / H

            # Find the "side" of the cone
            S = math.sqrt(H ** 2 + cone.r ** 2)

            # Find the half cone angle
            alpha = math.atan2(cone.r, H)

            for point in self.Points:
                if point[3] < 3:
                    P = np.array((point[0], point[1], point[3]))

                    # In order for P be inside the cone, it must satisfy the following two conditions:
                    # 1. |TP| <= S
                    # 2. Angle between <TP> and <TO> <= alpha

                    # Check condition 1
                    TP = np.linalg.norm(P - T)

                    if TP <= S:
                        # Check condition 2
                        if math.acos(round(np.dot((P - T), h) / TP, 6)) <= alpha:
                            num_points = num_points + 1

            if num_points > max_num_points:
                best_cone = Cone(cone.x, cone.y, cone.z, radius, height, cone.tip_x, cone.tip_y, cone.tip_z, type=type)
        return best_cone

    def add_best_sphere(self, radius, type="B", iterations=500):
        best_sphere = Sphere
        max_num_points = 0

        for i in range(0, iterations):
            sphere = self.add_sphere(radius)

            counter = 0
            for point in self.Points:
                if point[3] < 3:
                    if distance_finder(sphere.x, sphere.y, sphere.z, point[0], point[1],
                                       point[2]) <= sphere.r:
                        if point[3] < 3:
                            counter = counter + 1

            if counter > max_num_points:
                max_num_points = counter
                best_sphere = Sphere(sphere.x, sphere.y, sphere.z, sphere.r, type=type)
        return best_sphere

# %% [markdown]
# **Class of Sphere**

# %%
class Sphere:
    def __init__(self, origin_x, origin_y, origin_z, radius, type="B"):
        self.x = origin_x
        self.y = origin_y
        self.z = origin_z
        self.r = radius
        self.t = type

    def print(self):
        print(f"X: {self.x}, Y: {self.y}, Z: {self.z}, Radius: {self.r}")

    def graph(self):
      (X, Y, Z) = plotly_sphere(self.x, self.y, self.z, self.r)
      return go.Surface(x=X, y=Y, z=Z, opacity=DEFAULT_OPACITY, colorscale=['green', 'green'])

    def save(self):
      return [self.x, self.y, self.z, self.r, None, sphere_cost(self.r), volume_sphere(self.r), "Sphere", self.t,
                None, None, None,None]

# %% [markdown]
# **Class of Cone**

# %%
class Cone:
    def __init__(self, origin_x, origin_y, origin_z, radius, height, tip_x, tip_y, tip_z, type="B"):
        self.x = origin_x
        self.y = origin_y
        self.z = origin_z
        self.r = radius
        self.h = height
        self.tip_x = tip_x
        self.tip_y = tip_y
        self.tip_z = tip_z
        self.t = type

    def print(self):
        print(
            f"X: {self.x}, Y: {self.y}, Z: {self.z}, Radius: {self.r}, Height: {self.h}, Tip X: {self.tip_x}, Tip Y: {self.tip_y}, Tip Z: {self.tip_z}")

    def graph_sphere(self):
        (X, Y, Z) = plotly_sphere(self.x, self.y, self.z, self.r)
        return go.Surface(x=X, y=Y, z=Z, opacity=DEFAULT_OPACITY, colorscale=['green', 'green'])

    def graph_cone(self):
        return go.Cone(x=[self.x], y=[self.y], z=[self.z], u=[self.tip_x - self.x], v=[self.tip_y - self.x],
                       w=[self.tip_z - self.z], anchor="tail",
                       opacity=DEFAULT_OPACITY, colorscale=['green', 'green'])

    def save(self):
      return [self.x, self.y, self.z, self.r, self.h, cone_cost(self.r, self.h), volume_cone(self.r, self.h), "Cone",
                self.t, self.tip_x, self.tip_y, self.tip_z, None]

# %% [markdown]
# **Class of Rectangle**

# %%
class Rect:
    def __init__(self, start_x, len_x, start_y, len_y, start_z, len_z, rotate_degrees):
        self.s_x = start_x
        self.l_x = len_x
        self.s_y = start_y
        self.l_y = len_y
        self.s_z = start_z
        self.l_z = len_z
        self.deg = rotate_degrees
        self.t = "B"
        return

    def print(self):
        print(
            f"X: {self.l_x}, Start X: {self.s_x}, Y: {self.l_y}, Start Y: {self.s_y}, Z: {self.l_z}, Start Z: {self.s_z}, Degrees: {self.deg}")

    def graph(self):
        if self.deg == 0:
            x1 = self.s_x
            x2 = self.l_x + self.s_x
            y1 = self.s_y
            y2 = self.l_y + self.s_y
            z1 = self.s_z
            z2 = self.l_z + self.s_z
            return go.Mesh3d(x=[x1, x1, x2, x2, x1, x1, x2, x2],
                             y=[y1, y2, y2, y1, y1, y2, y2, y1],
                             z=[z1, z1, z1, z1, z2, z2, z2, z2],
                             i=[7, 0, 0, 0, 4, 4, 6, 6, 4, 0, 3, 2],
                             j=[3, 4, 1, 2, 5, 6, 5, 2, 0, 1, 6, 3],
                             k=[0, 7, 2, 3, 6, 7, 1, 1, 5, 5, 7, 6],
                             opacity=1, color='red')
        points = [
            (0, 0),
            (0, self.l_y),
            (self.l_x, self.l_y),
            (self.l_x, 0)
        ]

        rotated_points = []
        if self.deg > 0:
            for xy in points:
                rotated_points.append(translate(rotate(xy, math.radians(-1 * self.deg)), (self.s_x, self.s_y)))

        else:
            for xy in points:
                rotated_points.append(translate(rotate(xy, math.radians(-1 * self.deg)), (
                    round(self.s_x + math.sin(math.radians(-1 * self.deg)) * self.l_y), self.s_y)))

        z1 = self.s_z
        z2 = self.l_z + self.s_z
        return go.Mesh3d(x=[rotated_points[0][0], rotated_points[1][0], rotated_points[2][0], rotated_points[3][0],
                            rotated_points[0][0], rotated_points[1][0], rotated_points[2][0], rotated_points[3][0]],
                         y=[rotated_points[0][1], rotated_points[1][1], rotated_points[2][1], rotated_points[3][1],
                            rotated_points[0][1], rotated_points[1][1], rotated_points[2][1], rotated_points[3][1]],
                         z=[z1, z1, z1, z1, z2, z2, z2, z2],
                         i=[7, 0, 0, 0, 4, 4, 6, 6, 4, 0, 3, 2],
                         j=[3, 4, 1, 2, 5, 6, 5, 2, 0, 1, 6, 3],
                         k=[0, 7, 2, 3, 6, 7, 1, 1, 5, 5, 7, 6],
                         opacity=1, color='red')

# %% [markdown]
# #Run Model

# %%
if minimize.upper() == 'S':
    if is_spheres and is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors, special_grid=special_grid)
    elif is_spheres:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, stypes=sensors,
                special_grid=special_grid)
    elif is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors, special_grid=special_grid)
    else:
        nn = None
        exit()

    nn.run_minimize_nodes(iterations=iterate, save_all=is_save)

elif minimize.upper() == "C":
    if is_spheres and is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors, special_grid=special_grid)
    elif is_spheres:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, stypes=sensors,
                special_grid=special_grid)
    elif is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors, special_grid=special_grid)
    else:
        nn = None
        exit()
    nn.run_minimize_cost(iterations=iterate, save_all=is_save)

elif minimize.upper() == "X":
    if is_spheres and is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors)
    elif is_spheres:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, stypes=sensors)
    elif is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors)
    else:
        nn = None
        exit()

    nn.run_optimal_nodes(iterations=iterate, save_all=is_save)

else:
    if is_spheres and is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors)
    elif is_spheres:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, sphere_radii=sphere_radii, stypes=sensors)
    elif is_cones:
        nn = NN(grid_x=x, grid_y=y, grid_z=z, resolution=res, cone_radii=cone_radii,
                cone_heights=cone_heights, stypes=sensors)
    else:
        nn = None
        exit()

    nn.run_optimal_cost(iterations=iterate, save_all=is_save)
# Out:
# Iteration 0 Number of M Shapes:16
# Minimum Cost: 5378.406622945726
# Iteration 1 Number of M Shapes:15
# Minimum Cost: 5262.167694762903
# Iteration 2 Number of M Shapes:17
# Iteration 3 Number of M Shapes:15
# Minimum Cost: 5232.846163329398
# Iteration 4 Number of M Shapes:17
# Minimum Cost: 4882.034983678538
# Iteration 5 Number of M Shapes:9
# Minimum Cost: 3148.923036448169
# Iteration 6 Number of M Shapes:12
# Iteration 7 Number of M Shapes:7
# Iteration 8 Number of M Shapes:10
# Iteration 9 Number of M Shapes:7
# Minimum Cost: 2149.896572606615
# Iteration 10 Number of M Shapes:9
# Iteration 11 Number of M Shapes:7
# Iteration 12 Number of M Shapes:8
# Iteration 13 Number of M Shapes:7
# Iteration 14 Number of M Shapes:6
# Iteration 15 Number of M Shapes:6
# Iteration 16 Number of M Shapes:8
# Iteration 17 Number of M Shapes:8
# Iteration 18 Number of M Shapes:3
# Minimum Cost: 1520.5308443374597
# Iteration 19 Number of M Shapes:4
# Iteration 20 Number of M Shapes:6
# Iteration 21 Number of M Shapes:7
# Iteration 22 Number of M Shapes:3
# Iteration 23 Number of M Shapes:5
# Iteration 24 Number of M Shapes:3
# Iteration 25 Number of M Shapes:7
# Iteration 26 Number of M Shapes:4
# Iteration 27 Number of M Shapes:5
# Iteration 28 Number of M Shapes:4
# Iteration 29 Number of M Shapes:7
# Iteration 30 Number of M Shapes:6
# Iteration 31 Number of M Shapes:3
# Iteration 32 Number of M Shapes:4
# Iteration 33 Number of M Shapes:6
# Iteration 34 Number of M Shapes:5
# Minimum Cost: 1031.4895879286487
# Iteration 35 Number of M Shapes:4
# Iteration 36 Number of M Shapes:3
# Iteration 37 Number of M Shapes:3
# Iteration 38 Number of M Shapes:3
# Iteration 39 Number of M Shapes:6
# Iteration 40 Number of M Shapes:3
# Iteration 41 Number of M Shapes:2
# Iteration 42 Number of M Shapes:4
# Iteration 43 Number of M Shapes:5
# Iteration 44 Number of M Shapes:2
# Iteration 45 Number of M Shapes:6
# Iteration 46 Number of M Shapes:7
# Iteration 47 Number of M Shapes:3
# Iteration 48 Number of M Shapes:3
# Iteration 49 Number of M Shapes:3
# Iteration 50 Number of M Shapes:7
# Iteration 51 Number of M Shapes:6
# Iteration 52 Number of M Shapes:5
# Iteration 53 Number of M Shapes:3
# Iteration 54 Number of M Shapes:4
# Iteration 55 Number of M Shapes:3
# Iteration 56 Number of M Shapes:4
# Iteration 57 Number of M Shapes:5
# Iteration 58 Number of M Shapes:4
# Iteration 59 Number of M Shapes:4
# Iteration 60 Number of M Shapes:3
# Iteration 61 Number of M Shapes:3
# Iteration 62 Number of M Shapes:4
# Iteration 63 Number of M Shapes:5
# Iteration 64 Number of M Shapes:2
# Iteration 65 Number of M Shapes:4
# Iteration 66 Number of M Shapes:3
# Iteration 67 Number of M Shapes:2
# Iteration 68 Number of M Shapes:3
# Iteration 69 Number of M Shapes:5
# Iteration 70 Number of M Shapes:4
# Iteration 71 Number of M Shapes:4
# Iteration 72 Number of M Shapes:5
# Iteration 73 Number of M Shapes:2
# Iteration 74 Number of M Shapes:3
# Iteration 75 Number of M Shapes:3
# Iteration 76 Number of M Shapes:3
# Iteration 77 Number of M Shapes:5
# Iteration 78 Number of M Shapes:3
# Iteration 79 Number of M Shapes:2
# Iteration 80 Number of M Shapes:2
# Iteration 81 Number of M Shapes:6
# Iteration 82 Number of M Shapes:4
# Iteration 83 Number of M Shapes:3
# Iteration 84 Number of M Shapes:5
# Iteration 85 Number of M Shapes:6
# Iteration 86 Number of M Shapes:3
# Iteration 87 Number of M Shapes:4
# Iteration 88 Number of M Shapes:4
# Iteration 89 Number of M Shapes:3
# Iteration 90 Number of M Shapes:3
# Iteration 91 Number of M Shapes:3
# Iteration 92 Number of M Shapes:2
# Iteration 93 Number of M Shapes:2
# Iteration 94 Number of M Shapes:6
# Iteration 95 Number of M Shapes:2
# Iteration 96 Number of M Shapes:5
# Iteration 97 Number of M Shapes:4
# Iteration 98 Number of M Shapes:5
# Iteration 99 Number of M Shapes:4
# Iteration 100 Number of M Shapes:4
# Iteration 101 Number of M Shapes:4
# Iteration 102 Number of M Shapes:2
# Iteration 103 Number of M Shapes:4
# Iteration 104 Number of M Shapes:5
# Iteration 105 Number of M Shapes:3
# Iteration 106 Number of M Shapes:6
# Iteration 107 Number of M Shapes:4
# Iteration 108 Number of M Shapes:3
# Iteration 109 Number of M Shapes:5
# Iteration 110 Number of M Shapes:5
# Iteration 111 Number of M Shapes:4
# Iteration 112 Number of M Shapes:4
# Iteration 113 Number of M Shapes:4
# Iteration 114 Number of M Shapes:5
# Iteration 115 Number of M Shapes:3
# Iteration 116 Number of M Shapes:2
# Iteration 117 Number of M Shapes:4
# Iteration 118 Number of M Shapes:4
# Iteration 119 Number of M Shapes:4
# Iteration 120 Number of M Shapes:2
# Iteration 121 Number of M Shapes:3
# Iteration 122 Number of M Shapes:3
# Iteration 123 Number of M Shapes:2
# Iteration 124 Number of M Shapes:3
# Iteration 125 Number of M Shapes:4
# Iteration 126 Number of M Shapes:3
# Iteration 127 Number of M Shapes:5
# Iteration 128 Number of M Shapes:5
# Iteration 129 Number of M Shapes:4
# Iteration 130 Number of M Shapes:3
# Iteration 131 Number of M Shapes:4
# Iteration 132 Number of M Shapes:4
# Iteration 133 Number of M Shapes:3
# Iteration 134 Number of M Shapes:4
# Iteration 135 Number of M Shapes:5
# Iteration 136 Number of M Shapes:5
# Iteration 137 Number of M Shapes:3
# Iteration 138 Number of M Shapes:3
# Iteration 139 Number of M Shapes:2
# Minimum Cost: 942.4777960769379
# Iteration 140 Number of M Shapes:3
# Iteration 141 Number of M Shapes:4
# Iteration 142 Number of M Shapes:3
# Iteration 143 Number of M Shapes:4
# Iteration 144 Number of M Shapes:3
# Iteration 145 Number of M Shapes:5
# Iteration 146 Number of M Shapes:4
# Iteration 147 Number of M Shapes:5
# Iteration 148 Number of M Shapes:2
# Iteration 149 Number of M Shapes:2
# Iteration 150 Number of M Shapes:4
# Iteration 151 Number of M Shapes:3
# Iteration 152 Number of M Shapes:3
# Iteration 153 Number of M Shapes:4
# Iteration 154 Number of M Shapes:5
# Iteration 155 Number of M Shapes:6
# Iteration 156 Number of M Shapes:4
# Iteration 157 Number of M Shapes:2
# Iteration 158 Number of M Shapes:4
# Iteration 159 Number of M Shapes:2
# Iteration 160 Number of M Shapes:2
# Iteration 161 Number of M Shapes:5
# Iteration 162 Number of M Shapes:4
# Iteration 163 Number of M Shapes:4
# Iteration 164 Number of M Shapes:5
# Iteration 165 Number of M Shapes:3
# Iteration 166 Number of M Shapes:4
# Iteration 167 Number of M Shapes:2
# <ipython-input-14-467e4b97665c>:158: RuntimeWarning: invalid value encountered in scalar divide
#   if math.acos(round(np.dot((P - T), h) / TP, 6)) <= alpha:
# Iteration 168 Number of M Shapes:4
# Iteration 169 Number of M Shapes:2
# Iteration 170 Number of M Shapes:5
# Iteration 171 Number of M Shapes:2
# Iteration 172 Number of M Shapes:5
# Iteration 173 Number of M Shapes:3
# Iteration 174 Number of M Shapes:2
# Iteration 175 Number of M Shapes:4
# Iteration 176 Number of M Shapes:2
# Iteration 177 Number of M Shapes:4
# Iteration 178 Number of M Shapes:4
# Iteration 179 Number of M Shapes:3
# Iteration 180 Number of M Shapes:2
# Iteration 181 Number of M Shapes:4
# Iteration 182 Number of M Shapes:3
# Iteration 183 Number of M Shapes:3
# Iteration 184 Number of M Shapes:2
# Iteration 185 Number of M Shapes:3
# Iteration 186 Number of M Shapes:5
# Iteration 187 Number of M Shapes:2
# Iteration 188 Number of M Shapes:4
# Iteration 189 Number of M Shapes:4
# Iteration 190 Number of M Shapes:5
# Iteration 191 Number of M Shapes:4
# Iteration 192 Number of M Shapes:2
# Iteration 193 Number of M Shapes:2
# Iteration 194 Number of M Shapes:2
# Iteration 195 Number of M Shapes:4
# Iteration 196 Number of M Shapes:5
# Iteration 197 Number of M Shapes:4
# Iteration 198 Number of M Shapes:4
# Iteration 199 Number of M Shapes:4
# Iteration 200 Number of M Shapes:3
# Iteration 201 Number of M Shapes:2
# Iteration 202 Number of M Shapes:5
# Iteration 203 Number of M Shapes:4
# Iteration 204 Number of M Shapes:6
# Iteration 205 Number of M Shapes:5
# Iteration 206 Number of M Shapes:5
# Iteration 207 Number of M Shapes:3
# Iteration 208 Number of M Shapes:5
# Iteration 209 Number of M Shapes:2
# Iteration 210 Number of M Shapes:5
# Iteration 211 Number of M Shapes:2
# Iteration 212 Number of M Shapes:4
# Iteration 213 Number of M Shapes:2
# Iteration 214 Number of M Shapes:5
# Iteration 215 Number of M Shapes:4
# Iteration 216 Number of M Shapes:5
# Iteration 217 Number of M Shapes:3
# Iteration 218 Number of M Shapes:2
# Iteration 219 Number of M Shapes:2
# Iteration 220 Number of M Shapes:3
# Iteration 221 Number of M Shapes:3
# Iteration 222 Number of M Shapes:4
# Iteration 223 Number of M Shapes:4
# Iteration 224 Number of M Shapes:4
# Iteration 225 Number of M Shapes:3
# Iteration 226 Number of M Shapes:4
# Iteration 227 Number of M Shapes:3
# Iteration 228 Number of M Shapes:5
# Iteration 229 Number of M Shapes:2
# Iteration 230 Number of M Shapes:7
# Iteration 231 Number of M Shapes:3
# Minimum Cost: 861.8435846347998
# Iteration 232 Number of M Shapes:5
# Iteration 233 Number of M Shapes:2
# Iteration 234 Number of M Shapes:3
# Iteration 235 Number of M Shapes:2
# Iteration 236 Number of M Shapes:2
# Iteration 237 Number of M Shapes:2
# Iteration 238 Number of M Shapes:4
# Iteration 239 Number of M Shapes:3
# Iteration 240 Number of M Shapes:6
# Iteration 241 Number of M Shapes:2
# Iteration 242 Number of M Shapes:2
# Iteration 243 Number of M Shapes:3
# Iteration 244 Number of M Shapes:2
# Iteration 245 Number of M Shapes:2
# Iteration 246 Number of M Shapes:3
# Iteration 247 Number of M Shapes:2
# Iteration 248 Number of M Shapes:1
# Minimum Cost: 804.247719318987
# Iteration 249 Number of M Shapes:3
# Iteration 250 Number of M Shapes:4
# Iteration 251 Number of M Shapes:4
# Iteration 252 Number of M Shapes:2
# Iteration 253 Number of M Shapes:4
# Iteration 254 Number of M Shapes:5
# Iteration 255 Number of M Shapes:3
# Iteration 256 Number of M Shapes:4
# Iteration 257 Number of M Shapes:3
# Iteration 258 Number of M Shapes:2
# Iteration 259 Number of M Shapes:3
# Iteration 260 Number of M Shapes:2
# Iteration 261 Number of M Shapes:5
# Iteration 262 Number of M Shapes:4
# Iteration 263 Number of M Shapes:4
# Iteration 264 Number of M Shapes:5
# Iteration 265 Number of M Shapes:4
# Iteration 266 Number of M Shapes:2
# Iteration 267 Number of M Shapes:6
# Iteration 268 Number of M Shapes:2
# Iteration 269 Number of M Shapes:1
# Iteration 270 Number of M Shapes:3
# Iteration 271 Number of M Shapes:3
# Iteration 272 Number of M Shapes:2
# Iteration 273 Number of M Shapes:1
# Iteration 274 Number of M Shapes:2
# <ipython-input-14-467e4b97665c>:158: RuntimeWarning: invalid value encountered in scalar divide
#   if math.acos(round(np.dot((P - T), h) / TP, 6)) <= alpha:
# Iteration 275 Number of M Shapes:4
# Iteration 276 Number of M Shapes:2
# Iteration 277 Number of M Shapes:4
# Iteration 278 Number of M Shapes:2
# Iteration 279 Number of M Shapes:4
# Iteration 280 Number of M Shapes:4
# Iteration 281 Number of M Shapes:1
# Iteration 282 Number of M Shapes:2
# Iteration 283 Number of M Shapes:1
# Iteration 284 Number of M Shapes:4
# Iteration 285 Number of M Shapes:5
# Iteration 286 Number of M Shapes:2
# Iteration 287 Number of M Shapes:1
# Iteration 288 Number of M Shapes:4
# Iteration 289 Number of M Shapes:3
# Iteration 290 Number of M Shapes:4
# Iteration 291 Number of M Shapes:3
# Iteration 292 Number of M Shapes:3
# Iteration 293 Number of M Shapes:2
# Iteration 294 Number of M Shapes:4
# Iteration 295 Number of M Shapes:4
# Iteration 296 Number of M Shapes:1
# Iteration 297 Number of M Shapes:5
# Iteration 298 Number of M Shapes:2
# Iteration 299 Number of M Shapes:5
# Iteration 300 Number of M Shapes:2
# Iteration 301 Number of M Shapes:2
# Iteration 302 Number of M Shapes:1
# Iteration 303 Number of M Shapes:4
# Iteration 304 Number of M Shapes:3
# Iteration 305 Number of M Shapes:2
# Iteration 306 Number of M Shapes:4
# Iteration 307 Number of M Shapes:2
# Iteration 308 Number of M Shapes:2
# Iteration 309 Number of M Shapes:2
# Iteration 310 Number of M Shapes:1
# Iteration 311 Number of M Shapes:2
# Iteration 312 Number of M Shapes:4
# Iteration 313 Number of M Shapes:3
# Iteration 314 Number of M Shapes:4
# Iteration 315 Number of M Shapes:1
# Iteration 316 Number of M Shapes:4
# Iteration 317 Number of M Shapes:5
# Iteration 318 Number of M Shapes:3
# Iteration 319 Number of M Shapes:5
# Iteration 320 Number of M Shapes:2
# Iteration 321 Number of M Shapes:5
# Iteration 322 Number of M Shapes:5
# Iteration 323 Number of M Shapes:3
# Iteration 324 Number of M Shapes:2
# Iteration 325 Number of M Shapes:2
# Iteration 326 Number of M Shapes:4
# Iteration 327 Number of M Shapes:4
# Iteration 328 Number of M Shapes:3
# Iteration 329 Number of M Shapes:3
# Iteration 330 Number of M Shapes:4
# Iteration 331 Number of M Shapes:1
# Iteration 332 Number of M Shapes:3
# Iteration 333 Number of M Shapes:2
# Iteration 334 Number of M Shapes:2
# Iteration 335 Number of M Shapes:3
# Iteration 336 Number of M Shapes:4
# Iteration 337 Number of M Shapes:2
# Iteration 338 Number of M Shapes:4
# Iteration 339 Number of M Shapes:4
# Iteration 340 Number of M Shapes:1
# Iteration 341 Number of M Shapes:5
# Iteration 342 Number of M Shapes:2
# Iteration 343 Number of M Shapes:5
# Iteration 344 Number of M Shapes:2
# Iteration 345 Number of M Shapes:2
# Iteration 346 Number of M Shapes:4
# Iteration 347 Number of M Shapes:2
# Iteration 348 Number of M Shapes:2
# Iteration 349 Number of M Shapes:3
# Iteration 350 Number of M Shapes:2
# Iteration 351 Number of M Shapes:4
# Iteration 352 Number of M Shapes:6
# Iteration 353 Number of M Shapes:2
# Iteration 354 Number of M Shapes:2
# Iteration 355 Number of M Shapes:4
# Iteration 356 Number of M Shapes:4
# Iteration 357 Number of M Shapes:3
# Iteration 358 Number of M Shapes:1
# Iteration 359 Number of M Shapes:2
# Iteration 360 Number of M Shapes:3
# Iteration 361 Number of M Shapes:4
# Iteration 362 Number of M Shapes:2
# Iteration 363 Number of M Shapes:2
# Iteration 364 Number of M Shapes:3
# Iteration 365 Number of M Shapes:1
# Iteration 366 Number of M Shapes:3
# Iteration 367 Number of M Shapes:2
# Iteration 368 Number of M Shapes:7
# Iteration 369 Number of M Shapes:1
# Iteration 370 Number of M Shapes:4
# Iteration 371 Number of M Shapes:2
# Iteration 372 Number of M Shapes:4
# Iteration 373 Number of M Shapes:2
# Iteration 374 Number of M Shapes:2
# Iteration 375 Number of M Shapes:3
# Iteration 376 Number of M Shapes:4
# Iteration 377 Number of M Shapes:5
# Iteration 378 Number of M Shapes:5
# Iteration 379 Number of M Shapes:1
# Iteration 380 Number of M Shapes:1
# Iteration 381 Number of M Shapes:3
# Iteration 382 Number of M Shapes:3
# Iteration 383 Number of M Shapes:1
# Iteration 384 Number of M Shapes:4
# Iteration 385 Number of M Shapes:1
# Iteration 386 Number of M Shapes:3
# Iteration 387 Number of M Shapes:5
# Iteration 388 Number of M Shapes:2
# Iteration 389 Number of M Shapes:3
# Iteration 390 Number of M Shapes:3
# Iteration 391 Number of M Shapes:3
# Iteration 392 Number of M Shapes:2
# Iteration 393 Number of M Shapes:2
# Iteration 394 Number of M Shapes:3
# Iteration 395 Number of M Shapes:3
# Iteration 396 Number of M Shapes:4
# Iteration 397 Number of M Shapes:4
# Iteration 398 Number of M Shapes:3
# Iteration 399 Number of M Shapes:4
# Iteration 400 Number of M Shapes:3
# Iteration 401 Number of M Shapes:3
# Iteration 402 Number of M Shapes:3
# Iteration 403 Number of M Shapes:2
# Iteration 404 Number of M Shapes:4
# Iteration 405 Number of M Shapes:5
# Iteration 406 Number of M Shapes:2
# Iteration 407 Number of M Shapes:4
# Iteration 408 Number of M Shapes:3
# Iteration 409 Number of M Shapes:2
# Iteration 410 Number of M Shapes:5
# Iteration 411 Number of M Shapes:2
# Iteration 412 Number of M Shapes:1
# Iteration 413 Number of M Shapes:2
# Iteration 414 Number of M Shapes:4
# Iteration 415 Number of M Shapes:4
# Iteration 416 Number of M Shapes:1
# Iteration 417 Number of M Shapes:1
# Iteration 418 Number of M Shapes:1
# Iteration 419 Number of M Shapes:3
# Iteration 420 Number of M Shapes:2
# Iteration 421 Number of M Shapes:4
# Iteration 422 Number of M Shapes:2
# Iteration 423 Number of M Shapes:4
# Iteration 424 Number of M Shapes:3
# Iteration 425 Number of M Shapes:3
# Iteration 426 Number of M Shapes:2
# Iteration 427 Number of M Shapes:4
# Iteration 428 Number of M Shapes:2
# Iteration 429 Number of M Shapes:1
# Iteration 430 Number of M Shapes:5
# Iteration 431 Number of M Shapes:5
# Iteration 432 Number of M Shapes:4
# Iteration 433 Number of M Shapes:3
# Iteration 434 Number of M Shapes:4
# Iteration 435 Number of M Shapes:2
# Iteration 436 Number of M Shapes:1
# Iteration 437 Number of M Shapes:1
# Iteration 438 Number of M Shapes:2
# Iteration 439 Number of M Shapes:3
# Iteration 440 Number of M Shapes:2
# Iteration 441 Number of M Shapes:1
# Iteration 442 Number of M Shapes:1
# Iteration 443 Number of M Shapes:4
# Iteration 444 Number of M Shapes:2
# Iteration 445 Number of M Shapes:5
# Iteration 446 Number of M Shapes:2
# Iteration 447 Number of M Shapes:3
# Iteration 448 Number of M Shapes:4
# Iteration 449 Number of M Shapes:3
# Iteration 450 Number of M Shapes:4
# Iteration 451 Number of M Shapes:3
# Iteration 452 Number of M Shapes:4
# Iteration 453 Number of M Shapes:3
# Iteration 454 Number of M Shapes:3
# Iteration 455 Number of M Shapes:4
# Iteration 456 Number of M Shapes:4
# Iteration 457 Number of M Shapes:4
# Iteration 458 Number of M Shapes:1
# Iteration 459 Number of M Shapes:4
# Iteration 460 Number of M Shapes:3
# Iteration 461 Number of M Shapes:3
# Iteration 462 Number of M Shapes:4
# Iteration 463 Number of M Shapes:3
# Iteration 464 Number of M Shapes:4
# Iteration 465 Number of M Shapes:2
# Iteration 466 Number of M Shapes:1
# Iteration 467 Number of M Shapes:2
# Iteration 468 Number of M Shapes:3
# Iteration 469 Number of M Shapes:4
# Iteration 470 Number of M Shapes:5
# Iteration 471 Number of M Shapes:4
# Iteration 472 Number of M Shapes:2
# Iteration 473 Number of M Shapes:2
# Iteration 474 Number of M Shapes:4
# Iteration 475 Number of M Shapes:3
# Iteration 476 Number of M Shapes:4
# Iteration 477 Number of M Shapes:1
# Iteration 478 Number of M Shapes:1
# Iteration 479 Number of M Shapes:3
# Iteration 480 Number of M Shapes:4
# Iteration 481 Number of M Shapes:2
# Iteration 482 Number of M Shapes:4
# Iteration 483 Number of M Shapes:4
# Iteration 484 Number of M Shapes:5
# Iteration 485 Number of M Shapes:2
# Iteration 486 Number of M Shapes:3
# Iteration 487 Number of M Shapes:3
# Iteration 488 Number of M Shapes:3
# Iteration 489 Number of M Shapes:4
# Iteration 490 Number of M Shapes:2
# Iteration 491 Number of M Shapes:5
# Iteration 492 Number of M Shapes:1
# Iteration 493 Number of M Shapes:3
# Iteration 494 Number of M Shapes:2
# Iteration 495 Number of M Shapes:3
# Iteration 496 Number of M Shapes:3
# Iteration 497 Number of M Shapes:2
# Iteration 498 Number of M Shapes:2
# Iteration 499 Number of M Shapes:1
# Iteration 500 Number of M Shapes:3
# Iteration 501 Number of M Shapes:2
# Iteration 502 Number of M Shapes:4
# Iteration 503 Number of M Shapes:2
# Iteration 504 Number of M Shapes:4
# Iteration 505 Number of M Shapes:2
# Iteration 506 Number of M Shapes:6
# Iteration 507 Number of M Shapes:6
# Iteration 508 Number of M Shapes:1
# Iteration 509 Number of M Shapes:2
# Iteration 510 Number of M Shapes:2
# Iteration 511 Number of M Shapes:4
# Iteration 512 Number of M Shapes:3
# Iteration 513 Number of M Shapes:4
# Iteration 514 Number of M Shapes:4
# Iteration 515 Number of M Shapes:4
# Iteration 516 Number of M Shapes:4
# Iteration 517 Number of M Shapes:3
# Iteration 518 Number of M Shapes:5
# Iteration 519 Number of M Shapes:3
# Iteration 520 Number of M Shapes:6
# Iteration 521 Number of M Shapes:5
# Iteration 522 Number of M Shapes:2
# Iteration 523 Number of M Shapes:3
# Iteration 524 Number of M Shapes:2
# Iteration 525 Number of M Shapes:1
# Iteration 526 Number of M Shapes:2
# Iteration 527 Number of M Shapes:3
# Iteration 528 Number of M Shapes:2
# Iteration 529 Number of M Shapes:4
# Iteration 530 Number of M Shapes:4
# Iteration 531 Number of M Shapes:5
# Iteration 532 Number of M Shapes:3
# Iteration 533 Number of M Shapes:3
# Iteration 534 Number of M Shapes:3
# Iteration 535 Number of M Shapes:3
# Iteration 536 Number of M Shapes:3
# Iteration 537 Number of M Shapes:6
# Iteration 538 Number of M Shapes:2
# Iteration 539 Number of M Shapes:3
# Iteration 540 Number of M Shapes:5
# Iteration 541 Number of M Shapes:1
# Iteration 542 Number of M Shapes:2
# Iteration 543 Number of M Shapes:5
# Iteration 544 Number of M Shapes:1
# Iteration 545 Number of M Shapes:3
# Iteration 546 Number of M Shapes:4
# Iteration 547 Number of M Shapes:5
# Iteration 548 Number of M Shapes:4
# Iteration 549 Number of M Shapes:2
# Iteration 550 Number of M Shapes:3
# Iteration 551 Number of M Shapes:4
# Iteration 552 Number of M Shapes:2
# Iteration 553 Number of M Shapes:2
# Iteration 554 Number of M Shapes:4
# Iteration 555 Number of M Shapes:4
# Iteration 556 Number of M Shapes:3
# Iteration 557 Number of M Shapes:5
# Iteration 558 Number of M Shapes:4
# Iteration 559 Number of M Shapes:2
# Iteration 560 Number of M Shapes:2
# Iteration 561 Number of M Shapes:1
# Iteration 562 Number of M Shapes:4
# Iteration 563 Number of M Shapes:4
# Iteration 564 Number of M Shapes:3
# Iteration 565 Number of M Shapes:5
# Iteration 566 Number of M Shapes:1
# Iteration 567 Number of M Shapes:3
# Iteration 568 Number of M Shapes:2
# Iteration 569 Number of M Shapes:5
# Iteration 570 Number of M Shapes:1
# Iteration 571 Number of M Shapes:1
# Iteration 572 Number of M Shapes:5
# Iteration 573 Number of M Shapes:2
# Iteration 574 Number of M Shapes:4
# Iteration 575 Number of M Shapes:3
# Iteration 576 Number of M Shapes:3
# Iteration 577 Number of M Shapes:4
# Iteration 578 Number of M Shapes:3
# Iteration 579 Number of M Shapes:3
# Iteration 580 Number of M Shapes:2
# Iteration 581 Number of M Shapes:3
# Iteration 582 Number of M Shapes:2
# Iteration 583 Number of M Shapes:3
# Iteration 584 Number of M Shapes:4
# Iteration 585 Number of M Shapes:2
# Iteration 586 Number of M Shapes:3
# Iteration 587 Number of M Shapes:1
# Iteration 588 Number of M Shapes:2
# Iteration 589 Number of M Shapes:3
# Iteration 590 Number of M Shapes:2
# Iteration 591 Number of M Shapes:4
# Iteration 592 Number of M Shapes:4
# Iteration 593 Number of M Shapes:4
# Iteration 594 Number of M Shapes:1
# Iteration 595 Number of M Shapes:3
# Iteration 596 Number of M Shapes:3
# Iteration 597 Number of M Shapes:3
# Iteration 598 Number of M Shapes:2
# Iteration 599 Number of M Shapes:4
# Iteration 600 Number of M Shapes:5
# Iteration 601 Number of M Shapes:3
# Iteration 602 Number of M Shapes:4
# Iteration 603 Number of M Shapes:1
# Iteration 604 Number of M Shapes:4
# Iteration 605 Number of M Shapes:4
# Iteration 606 Number of M Shapes:3
# Iteration 607 Number of M Shapes:4
# Iteration 608 Number of M Shapes:4
# Iteration 609 Number of M Shapes:2
# Iteration 610 Number of M Shapes:4
# Iteration 611 Number of M Shapes:5
# Iteration 612 Number of M Shapes:2
# Iteration 613 Number of M Shapes:5
# Iteration 614 Number of M Shapes:4
# Iteration 615 Number of M Shapes:4
# Iteration 616 Number of M Shapes:3
# Iteration 617 Number of M Shapes:4
# Iteration 618 Number of M Shapes:4
# Iteration 619 Number of M Shapes:2
# Iteration 620 Number of M Shapes:2
# Iteration 621 Number of M Shapes:2
# Iteration 622 Number of M Shapes:4
# Iteration 623 Number of M Shapes:6
# Iteration 624 Number of M Shapes:2
# Iteration 625 Number of M Shapes:2
# Iteration 626 Number of M Shapes:3
# Iteration 627 Number of M Shapes:2
# Iteration 628 Number of M Shapes:3
# Iteration 629 Number of M Shapes:4
# Iteration 630 Number of M Shapes:1
# Iteration 631 Number of M Shapes:3
# Iteration 632 Number of M Shapes:3
# Iteration 633 Number of M Shapes:6
# Iteration 634 Number of M Shapes:2
# Iteration 635 Number of M Shapes:3
# Iteration 636 Number of M Shapes:3
# Iteration 637 Number of M Shapes:4
# Iteration 638 Number of M Shapes:3
# Iteration 639 Number of M Shapes:2
# Iteration 640 Number of M Shapes:2
# Iteration 641 Number of M Shapes:4
# Iteration 642 Number of M Shapes:3
# Iteration 643 Number of M Shapes:3
# Iteration 644 Number of M Shapes:4
# Iteration 645 Number of M Shapes:4
# Iteration 646 Number of M Shapes:2
# Iteration 647 Number of M Shapes:7
# Iteration 648 Number of M Shapes:4
# Iteration 649 Number of M Shapes:2
# Iteration 650 Number of M Shapes:3
# Iteration 651 Number of M Shapes:4
# Iteration 652 Number of M Shapes:2
# Iteration 653 Number of M Shapes:2
# Iteration 654 Number of M Shapes:1
# Iteration 655 Number of M Shapes:4
# Iteration 656 Number of M Shapes:2
# Iteration 657 Number of M Shapes:3
# Iteration 658 Number of M Shapes:4
# Iteration 659 Number of M Shapes:5
# Iteration 660 Number of M Shapes:3
# Iteration 661 Number of M Shapes:3
# Iteration 662 Number of M Shapes:4
# Iteration 663 Number of M Shapes:3
# Iteration 664 Number of M Shapes:3
# Iteration 665 Number of M Shapes:4
# Iteration 666 Number of M Shapes:2
# Iteration 667 Number of M Shapes:4
# Iteration 668 Number of M Shapes:2
# Iteration 669 Number of M Shapes:3
# Iteration 670 Number of M Shapes:1
# Iteration 671 Number of M Shapes:1
# Iteration 672 Number of M Shapes:4
# Iteration 673 Number of M Shapes:4
# Iteration 674 Number of M Shapes:4
# Iteration 675 Number of M Shapes:4
# Iteration 676 Number of M Shapes:4
# Iteration 677 Number of M Shapes:4
# Iteration 678 Number of M Shapes:1
# Iteration 679 Number of M Shapes:1
# Iteration 680 Number of M Shapes:3
# Iteration 681 Number of M Shapes:3
# Iteration 682 Number of M Shapes:3
# Iteration 683 Number of M Shapes:6
# Iteration 684 Number of M Shapes:4
# Iteration 685 Number of M Shapes:3
# Iteration 686 Number of M Shapes:1
# Iteration 687 Number of M Shapes:4
# Iteration 688 Number of M Shapes:4
# Iteration 689 Number of M Shapes:2
# Iteration 690 Number of M Shapes:4
# Iteration 691 Number of M Shapes:4
# Iteration 692 Number of M Shapes:2
# Iteration 693 Number of M Shapes:6
# Iteration 694 Number of M Shapes:4
# Iteration 695 Number of M Shapes:2
# Iteration 696 Number of M Shapes:7
# Iteration 697 Number of M Shapes:4
# Iteration 698 Number of M Shapes:4
# Iteration 699 Number of M Shapes:3
# Iteration 700 Number of M Shapes:4
# Iteration 701 Number of M Shapes:4
# Iteration 702 Number of M Shapes:3
# Iteration 703 Number of M Shapes:2
# Iteration 704 Number of M Shapes:3
# Iteration 705 Number of M Shapes:2
# Iteration 706 Number of M Shapes:3
# Iteration 707 Number of M Shapes:1
# Iteration 708 Number of M Shapes:1
# Iteration 709 Number of M Shapes:4
# Iteration 710 Number of M Shapes:2
# Iteration 711 Number of M Shapes:4
# Iteration 712 Number of M Shapes:2
# Iteration 713 Number of M Shapes:4
# Iteration 714 Number of M Shapes:5
# Iteration 715 Number of M Shapes:1
# Iteration 716 Number of M Shapes:4
# Iteration 717 Number of M Shapes:5
# Iteration 718 Number of M Shapes:2
# Iteration 719 Number of M Shapes:3
# Iteration 720 Number of M Shapes:5
# Iteration 721 Number of M Shapes:3
# Iteration 722 Number of M Shapes:5
# Iteration 723 Number of M Shapes:2
# Iteration 724 Number of M Shapes:2
# Iteration 725 Number of M Shapes:4
# Iteration 726 Number of M Shapes:3
# Iteration 727 Number of M Shapes:5
# Iteration 728 Number of M Shapes:2
# Iteration 729 Number of M Shapes:3
# Iteration 730 Number of M Shapes:1
# Iteration 731 Number of M Shapes:2
# Iteration 732 Number of M Shapes:4
# Iteration 733 Number of M Shapes:2
# Iteration 734 Number of M Shapes:3
# Iteration 735 Number of M Shapes:5
# Iteration 736 Number of M Shapes:4
# Iteration 737 Number of M Shapes:3
# Iteration 738 Number of M Shapes:3
# Iteration 739 Number of M Shapes:6
# Iteration 740 Number of M Shapes:2
# Iteration 741 Number of M Shapes:4
# Iteration 742 Number of M Shapes:4
# Iteration 743 Number of M Shapes:2
# Iteration 744 Number of M Shapes:2
# Iteration 745 Number of M Shapes:2
# Iteration 746 Number of M Shapes:3
# Iteration 747 Number of M Shapes:4
# Iteration 748 Number of M Shapes:3
# Iteration 749 Number of M Shapes:4
# Iteration 750 Number of M Shapes:2
# Iteration 751 Number of M Shapes:2
# Minimum Cost: 593.7610115284708
# Iteration 752 Number of M Shapes:2
# Iteration 753 Number of M Shapes:4
# Iteration 754 Number of M Shapes:3
# Iteration 755 Number of M Shapes:4
# Iteration 756 Number of M Shapes:3
# Iteration 757 Number of M Shapes:4
# Iteration 758 Number of M Shapes:1
# Iteration 759 Number of M Shapes:1
# Iteration 760 Number of M Shapes:2
# Iteration 761 Number of M Shapes:5
# Iteration 762 Number of M Shapes:2
# Iteration 763 Number of M Shapes:2
# Iteration 764 Number of M Shapes:2
# Iteration 765 Number of M Shapes:4
# Iteration 766 Number of M Shapes:2
# Iteration 767 Number of M Shapes:1
# Iteration 768 Number of M Shapes:2
# Iteration 769 Number of M Shapes:1
# Iteration 770 Number of M Shapes:4
# Iteration 771 Number of M Shapes:3
# Iteration 772 Number of M Shapes:3
# Iteration 773 Number of M Shapes:4
# Iteration 774 Number of M Shapes:3
# Iteration 775 Number of M Shapes:3
# Iteration 776 Number of M Shapes:1
# Iteration 777 Number of M Shapes:2
# Iteration 778 Number of M Shapes:4
# Iteration 779 Number of M Shapes:4
# Iteration 780 Number of M Shapes:2
# Iteration 781 Number of M Shapes:3
# Iteration 782 Number of M Shapes:1
# Iteration 783 Number of M Shapes:3
# Iteration 784 Number of M Shapes:3
# Iteration 785 Number of M Shapes:1
# Iteration 786 Number of M Shapes:1
# Iteration 787 Number of M Shapes:4
# Iteration 788 Number of M Shapes:1
# Iteration 789 Number of M Shapes:2
# Iteration 790 Number of M Shapes:2
# Iteration 791 Number of M Shapes:4
# Iteration 792 Number of M Shapes:1
# Iteration 793 Number of M Shapes:1
# Iteration 794 Number of M Shapes:3
# Iteration 795 Number of M Shapes:3
# Iteration 796 Number of M Shapes:3
# Iteration 797 Number of M Shapes:1
# Iteration 798 Number of M Shapes:1
# Iteration 799 Number of M Shapes:3
# Iteration 800 Number of M Shapes:4
# Iteration 801 Number of M Shapes:1
# Iteration 802 Number of M Shapes:4
# Iteration 803 Number of M Shapes:1
# Iteration 804 Number of M Shapes:3
# Iteration 805 Number of M Shapes:5
# Iteration 806 Number of M Shapes:3
# Iteration 807 Number of M Shapes:1
# Iteration 808 Number of M Shapes:3
# Iteration 809 Number of M Shapes:2
# Iteration 810 Number of M Shapes:2
# Iteration 811 Number of M Shapes:3
# Iteration 812 Number of M Shapes:1
# Iteration 813 Number of M Shapes:3
# Iteration 814 Number of M Shapes:3
# Iteration 815 Number of M Shapes:3
# Iteration 816 Number of M Shapes:2
# Iteration 817 Number of M Shapes:1
# Iteration 818 Number of M Shapes:3
# Iteration 819 Number of M Shapes:2
# Iteration 820 Number of M Shapes:3
# Iteration 821 Number of M Shapes:1
# Iteration 822 Number of M Shapes:1
# Iteration 823 Number of M Shapes:3
# Iteration 824 Number of M Shapes:5
# Iteration 825 Number of M Shapes:3
# Iteration 826 Number of M Shapes:1
# Iteration 827 Number of M Shapes:4
# Iteration 828 Number of M Shapes:1
# Iteration 829 Number of M Shapes:1
# Iteration 830 Number of M Shapes:1
# Iteration 831 Number of M Shapes:5
# Iteration 832 Number of M Shapes:3
# Iteration 833 Number of M Shapes:2
# Iteration 834 Number of M Shapes:2
# Iteration 835 Number of M Shapes:2
# Iteration 836 Number of M Shapes:2
# Iteration 837 Number of M Shapes:3
# Iteration 838 Number of M Shapes:1
# Iteration 839 Number of M Shapes:3
# Iteration 840 Number of M Shapes:4
# Iteration 841 Number of M Shapes:1
# Iteration 842 Number of M Shapes:2
# Iteration 843 Number of M Shapes:3
# Iteration 844 Number of M Shapes:3
# Iteration 845 Number of M Shapes:3
# Iteration 846 Number of M Shapes:1
# Iteration 847 Number of M Shapes:1
# Iteration 848 Number of M Shapes:2
# Iteration 849 Number of M Shapes:3
# Iteration 850 Number of M Shapes:1
# Iteration 851 Number of M Shapes:3
# Iteration 852 Number of M Shapes:4
# Iteration 853 Number of M Shapes:4
# Iteration 854 Number of M Shapes:1
# Iteration 855 Number of M Shapes:3
# Iteration 856 Number of M Shapes:1
# Iteration 857 Number of M Shapes:4
# Iteration 858 Number of M Shapes:2
# Iteration 859 Number of M Shapes:1
# Iteration 860 Number of M Shapes:3
# Iteration 861 Number of M Shapes:2
# Iteration 862 Number of M Shapes:3
# Iteration 863 Number of M Shapes:2
# Iteration 864 Number of M Shapes:4
# Iteration 865 Number of M Shapes:2
# Iteration 866 Number of M Shapes:2
# Iteration 867 Number of M Shapes:2
# Iteration 868 Number of M Shapes:1
# Iteration 869 Number of M Shapes:1
# <ipython-input-14-467e4b97665c>:158: RuntimeWarning: invalid value encountered in scalar divide
#   if math.acos(round(np.dot((P - T), h) / TP, 6)) <= alpha:
# Iteration 870 Number of M Shapes:2
# Iteration 871 Number of M Shapes:3
# Iteration 872 Number of M Shapes:2
# Iteration 873 Number of M Shapes:1
# Iteration 874 Number of M Shapes:1
# Iteration 875 Number of M Shapes:4
# Iteration 876 Number of M Shapes:1
# Iteration 877 Number of M Shapes:4
# Iteration 878 Number of M Shapes:2
# Iteration 879 Number of M Shapes:2
# Iteration 880 Number of M Shapes:3
# Iteration 881 Number of M Shapes:1
# Iteration 882 Number of M Shapes:1
# Iteration 883 Number of M Shapes:1
# Iteration 884 Number of M Shapes:1
# Iteration 885 Number of M Shapes:1
# Iteration 886 Number of M Shapes:1
# Iteration 887 Number of M Shapes:2
# Iteration 888 Number of M Shapes:4
# Iteration 889 Number of M Shapes:2
# Iteration 890 Number of M Shapes:1
# Iteration 891 Number of M Shapes:4
# Iteration 892 Number of M Shapes:1
# Iteration 893 Number of M Shapes:2
# Iteration 894 Number of M Shapes:2
# Iteration 895 Number of M Shapes:2
# Iteration 896 Number of M Shapes:5
# Iteration 897 Number of M Shapes:4
# Iteration 898 Number of M Shapes:1
# Iteration 899 Number of M Shapes:3
# Iteration 900 Number of M Shapes:3
# Iteration 901 Number of M Shapes:2
# Iteration 902 Number of M Shapes:1
# Iteration 903 Number of M Shapes:1
# Iteration 904 Number of M Shapes:3
# Iteration 905 Number of M Shapes:2
# Iteration 906 Number of M Shapes:1
# Iteration 907 Number of M Shapes:3
# Iteration 908 Number of M Shapes:1
# Iteration 909 Number of M Shapes:1
# Iteration 910 Number of M Shapes:1
# Iteration 911 Number of M Shapes:2
# Iteration 912 Number of M Shapes:4
# Iteration 913 Number of M Shapes:2
# Iteration 914 Number of M Shapes:4
# Iteration 915 Number of M Shapes:1
# Iteration 916 Number of M Shapes:1
# Iteration 917 Number of M Shapes:1
# Iteration 918 Number of M Shapes:1
# Iteration 919 Number of M Shapes:1
# Iteration 920 Number of M Shapes:1
# Iteration 921 Number of M Shapes:2
# Iteration 922 Number of M Shapes:3
# Iteration 923 Number of M Shapes:2
# Iteration 924 Number of M Shapes:3
# Iteration 925 Number of M Shapes:2
# Iteration 926 Number of M Shapes:3
# Iteration 927 Number of M Shapes:2
# Iteration 928 Number of M Shapes:1
# Iteration 929 Number of M Shapes:2
# Iteration 930 Number of M Shapes:3
# Iteration 931 Number of M Shapes:5
# Iteration 932 Number of M Shapes:2
# Iteration 933 Number of M Shapes:1
# Iteration 934 Number of M Shapes:3
# Iteration 935 Number of M Shapes:1
# Iteration 936 Number of M Shapes:3
# Iteration 937 Number of M Shapes:4
# Iteration 938 Number of M Shapes:1
# Iteration 939 Number of M Shapes:2
# Iteration 940 Number of M Shapes:2
# Iteration 941 Number of M Shapes:2
# Iteration 942 Number of M Shapes:3
# Iteration 943 Number of M Shapes:3
# Iteration 944 Number of M Shapes:3
# Iteration 945 Number of M Shapes:1
# Iteration 946 Number of M Shapes:3
# Iteration 947 Number of M Shapes:2
# Iteration 948 Number of M Shapes:2
# Iteration 949 Number of M Shapes:1
# Iteration 950 Number of M Shapes:2
# Iteration 951 Number of M Shapes:1
# Iteration 952 Number of M Shapes:3
# Iteration 953 Number of M Shapes:1
# Iteration 954 Number of M Shapes:4
# Iteration 955 Number of M Shapes:4
# Iteration 956 Number of M Shapes:1
# Iteration 957 Number of M Shapes:2
# Iteration 958 Number of M Shapes:1
# Iteration 959 Number of M Shapes:2
# Iteration 960 Number of M Shapes:2
# Iteration 961 Number of M Shapes:3
# Iteration 962 Number of M Shapes:3
# Iteration 963 Number of M Shapes:3
# Iteration 964 Number of M Shapes:1
# Iteration 965 Number of M Shapes:3
# Iteration 966 Number of M Shapes:3
# Iteration 967 Number of M Shapes:5
# Iteration 968 Number of M Shapes:3
# Iteration 969 Number of M Shapes:4
# Iteration 970 Number of M Shapes:1
# Iteration 971 Number of M Shapes:1
# Iteration 972 Number of M Shapes:1
# Iteration 973 Number of M Shapes:3
# Iteration 974 Number of M Shapes:3
# Iteration 975 Number of M Shapes:1
# Iteration 976 Number of M Shapes:3
# Iteration 977 Number of M Shapes:3
# Iteration 978 Number of M Shapes:3
# Iteration 979 Number of M Shapes:4
# Iteration 980 Number of M Shapes:1
# Iteration 981 Number of M Shapes:2
# Iteration 982 Number of M Shapes:5
# Iteration 983 Number of M Shapes:2
# Iteration 984 Number of M Shapes:2
# Iteration 985 Number of M Shapes:1
# Iteration 986 Number of M Shapes:2
# Iteration 987 Number of M Shapes:3
# Iteration 988 Number of M Shapes:5
# Iteration 989 Number of M Shapes:4
# Iteration 990 Number of M Shapes:2
# Iteration 991 Number of M Shapes:1
# Iteration 992 Number of M Shapes:1
# Iteration 993 Number of M Shapes:3
# Iteration 994 Number of M Shapes:2
# Iteration 995 Number of M Shapes:1
# Iteration 996 Number of M Shapes:2
# Iteration 997 Number of M Shapes:2
# Iteration 998 Number of M Shapes:3
# Iteration 999 Number of M Shapes:1
# Iteration 1000 Number of M Shapes:2
# Iteration 1001 Number of M Shapes:1
# Iteration 1002 Number of M Shapes:1
# Iteration 1003 Number of M Shapes:3
# Iteration 1004 Number of M Shapes:4
# Iteration 1005 Number of M Shapes:3
# Iteration 1006 Number of M Shapes:4
# Iteration 1007 Number of M Shapes:3
# Iteration 1008 Number of M Shapes:4
# Iteration 1009 Number of M Shapes:3
# Iteration 1010 Number of M Shapes:2
# Iteration 1011 Number of M Shapes:1
# Iteration 1012 Number of M Shapes:2
# Iteration 1013 Number of M Shapes:2
# Iteration 1014 Number of M Shapes:2
# Iteration 1015 Number of M Shapes:3
# Iteration 1016 Number of M Shapes:2
# Iteration 1017 Number of M Shapes:1
# Iteration 1018 Number of M Shapes:3
# Iteration 1019 Number of M Shapes:1
# Iteration 1020 Number of M Shapes:4
# Iteration 1021 Number of M Shapes:1
# Iteration 1022 Number of M Shapes:3
# Iteration 1023 Number of M Shapes:3
# Iteration 1024 Number of M Shapes:4
# Iteration 1025 Number of M Shapes:2
# Iteration 1026 Number of M Shapes:2
# Iteration 1027 Number of M Shapes:2
# Iteration 1028 Number of M Shapes:3
# Iteration 1029 Number of M Shapes:4
# Iteration 1030 Number of M Shapes:2
# Iteration 1031 Number of M Shapes:1
# Iteration 1032 Number of M Shapes:1
# Iteration 1033 Number of M Shapes:3
# Iteration 1034 Number of M Shapes:1
# Iteration 1035 Number of M Shapes:2
# Iteration 1036 Number of M Shapes:2
# Iteration 1037 Number of M Shapes:2
# Iteration 1038 Number of M Shapes:3
# Iteration 1039 Number of M Shapes:2
# Iteration 1040 Number of M Shapes:4
# Iteration 1041 Number of M Shapes:1
# Iteration 1042 Number of M Shapes:1
# Iteration 1043 Number of M Shapes:2
# Iteration 1044 Number of M Shapes:1
# Iteration 1045 Number of M Shapes:4
# Iteration 1046 Number of M Shapes:4
# Iteration 1047 Number of M Shapes:2
# Iteration 1048 Number of M Shapes:3
# Iteration 1049 Number of M Shapes:1
# Iteration 1050 Number of M Shapes:2
# Iteration 1051 Number of M Shapes:2
# Iteration 1052 Number of M Shapes:2
# Iteration 1053 Number of M Shapes:2
# Iteration 1054 Number of M Shapes:2
# Iteration 1055 Number of M Shapes:3
# Iteration 1056 Number of M Shapes:2
# Iteration 1057 Number of M Shapes:2
# Iteration 1058 Number of M Shapes:1
# Iteration 1059 Number of M Shapes:1
# Iteration 1060 Number of M Shapes:3
# Iteration 1061 Number of M Shapes:2
# Iteration 1062 Number of M Shapes:1
# Iteration 1063 Number of M Shapes:3
# Iteration 1064 Number of M Shapes:4
# Iteration 1065 Number of M Shapes:3
# Iteration 1066 Number of M Shapes:1
# Iteration 1067 Number of M Shapes:3
# Iteration 1068 Number of M Shapes:2
# Iteration 1069 Number of M Shapes:2
# Iteration 1070 Number of M Shapes:2
# Iteration 1071 Number of M Shapes:3
# Iteration 1072 Number of M Shapes:1
# Iteration 1073 Number of M Shapes:3
# Iteration 1074 Number of M Shapes:1
# Iteration 1075 Number of M Shapes:3
# Iteration 1076 Number of M Shapes:2
# Iteration 1077 Number of M Shapes:5
# Iteration 1078 Number of M Shapes:2
# Iteration 1079 Number of M Shapes:1
# Iteration 1080 Number of M Shapes:1
# Iteration 1081 Number of M Shapes:3
# Iteration 1082 Number of M Shapes:3
# Iteration 1083 Number of M Shapes:4
# Iteration 1084 Number of M Shapes:3
# Iteration 1085 Number of M Shapes:2
# Iteration 1086 Number of M Shapes:2
# Iteration 1087 Number of M Shapes:2
# Iteration 1088 Number of M Shapes:3
# Iteration 1089 Number of M Shapes:2
# Iteration 1090 Number of M Shapes:4
# Iteration 1091 Number of M Shapes:3
# Iteration 1092 Number of M Shapes:1
# Iteration 1093 Number of M Shapes:4
# Iteration 1094 Number of M Shapes:2
# Iteration 1095 Number of M Shapes:3
# Iteration 1096 Number of M Shapes:2
# Iteration 1097 Number of M Shapes:3
# Iteration 1098 Number of M Shapes:3
# Iteration 1099 Number of M Shapes:6
# Iteration 1100 Number of M Shapes:2
# Iteration 1101 Number of M Shapes:1
# Iteration 1102 Number of M Shapes:3
# Iteration 1103 Number of M Shapes:4
# Iteration 1104 Number of M Shapes:3
# Iteration 1105 Number of M Shapes:2
# Iteration 1106 Number of M Shapes:3
# Iteration 1107 Number of M Shapes:3
# Iteration 1108 Number of M Shapes:1
# Iteration 1109 Number of M Shapes:1
# Iteration 1110 Number of M Shapes:4
# Iteration 1111 Number of M Shapes:1
# Iteration 1112 Number of M Shapes:2
# Iteration 1113 Number of M Shapes:1
# Iteration 1114 Number of M Shapes:3
# Iteration 1115 Number of M Shapes:4
# Iteration 1116 Number of M Shapes:3
# Iteration 1117 Number of M Shapes:3
# Iteration 1118 Number of M Shapes:2
# Iteration 1119 Number of M Shapes:2
# Iteration 1120 Number of M Shapes:1
# Iteration 1121 Number of M Shapes:3
# Iteration 1122 Number of M Shapes:2
# Iteration 1123 Number of M Shapes:3
# Iteration 1124 Number of M Shapes:1
# Iteration 1125 Number of M Shapes:4
# Iteration 1126 Number of M Shapes:2
# Iteration 1127 Number of M Shapes:3
# Iteration 1128 Number of M Shapes:3
# Iteration 1129 Number of M Shapes:3
# Iteration 1130 Number of M Shapes:2
# Iteration 1131 Number of M Shapes:1
# Iteration 1132 Number of M Shapes:3
# Iteration 1133 Number of M Shapes:3
# Iteration 1134 Number of M Shapes:4
# Iteration 1135 Number of M Shapes:2
# Iteration 1136 Number of M Shapes:3
# Iteration 1137 Number of M Shapes:3
# Iteration 1138 Number of M Shapes:2
# Iteration 1139 Number of M Shapes:1
# Iteration 1140 Number of M Shapes:1
# Iteration 1141 Number of M Shapes:3
# Iteration 1142 Number of M Shapes:1
# Iteration 1143 Number of M Shapes:1
# Iteration 1144 Number of M Shapes:1
# Iteration 1145 Number of M Shapes:1
# Iteration 1146 Number of M Shapes:3
# Iteration 1147 Number of M Shapes:3
# Iteration 1148 Number of M Shapes:3
# Iteration 1149 Number of M Shapes:3
# Iteration 1150 Number of M Shapes:2
# Iteration 1151 Number of M Shapes:4
# Iteration 1152 Number of M Shapes:3
# Iteration 1153 Number of M Shapes:3
# Iteration 1154 Number of M Shapes:2
# Iteration 1155 Number of M Shapes:2
# Iteration 1156 Number of M Shapes:2
# Iteration 1157 Number of M Shapes:1
# Iteration 1158 Number of M Shapes:3
# Iteration 1159 Number of M Shapes:2
# Iteration 1160 Number of M Shapes:2
# Iteration 1161 Number of M Shapes:2
# Iteration 1162 Number of M Shapes:3
# Iteration 1163 Number of M Shapes:2
# Iteration 1164 Number of M Shapes:1
# Iteration 1165 Number of M Shapes:2
# Iteration 1166 Number of M Shapes:1
# Iteration 1167 Number of M Shapes:1
# Iteration 1168 Number of M Shapes:1
# Iteration 1169 Number of M Shapes:2
# Iteration 1170 Number of M Shapes:3
# Iteration 1171 Number of M Shapes:1
# Iteration 1172 Number of M Shapes:4
# Iteration 1173 Number of M Shapes:2
# Iteration 1174 Number of M Shapes:2
# Iteration 1175 Number of M Shapes:3
# Iteration 1176 Number of M Shapes:2
# Iteration 1177 Number of M Shapes:4
# Iteration 1178 Number of M Shapes:2
# Iteration 1179 Number of M Shapes:1
# Iteration 1180 Number of M Shapes:3
# Iteration 1181 Number of M Shapes:3
# Iteration 1182 Number of M Shapes:3
# Iteration 1183 Number of M Shapes:3
# Iteration 1184 Number of M Shapes:4
# Iteration 1185 Number of M Shapes:1
# Iteration 1186 Number of M Shapes:1
# Iteration 1187 Number of M Shapes:2
# Iteration 1188 Number of M Shapes:4
# Iteration 1189 Number of M Shapes:5
# Iteration 1190 Number of M Shapes:4
# Iteration 1191 Number of M Shapes:4
# Iteration 1192 Number of M Shapes:5
# Iteration 1193 Number of M Shapes:3
# Iteration 1194 Number of M Shapes:4
# Iteration 1195 Number of M Shapes:3
# Iteration 1196 Number of M Shapes:3
# Iteration 1197 Number of M Shapes:2
# Iteration 1198 Number of M Shapes:3
# Iteration 1199 Number of M Shapes:3
# Iteration 1200 Number of M Shapes:3
# Iteration 1201 Number of M Shapes:4
# Iteration 1202 Number of M Shapes:1
# Iteration 1203 Number of M Shapes:2
# Iteration 1204 Number of M Shapes:2
# Iteration 1205 Number of M Shapes:1
# Iteration 1206 Number of M Shapes:3
# Iteration 1207 Number of M Shapes:3
# Iteration 1208 Number of M Shapes:4
# Iteration 1209 Number of M Shapes:1
# Iteration 1210 Number of M Shapes:4
# Iteration 1211 Number of M Shapes:1
# Iteration 1212 Number of M Shapes:2
# Iteration 1213 Number of M Shapes:2
# Iteration 1214 Number of M Shapes:4
# Iteration 1215 Number of M Shapes:4
# Iteration 1216 Number of M Shapes:3
# Iteration 1217 Number of M Shapes:1
# Iteration 1218 Number of M Shapes:4
# Iteration 1219 Number of M Shapes:1
# Iteration 1220 Number of M Shapes:1
# Iteration 1221 Number of M Shapes:3
# Iteration 1222 Number of M Shapes:1
# Iteration 1223 Number of M Shapes:2
# Iteration 1224 Number of M Shapes:4
# Iteration 1225 Number of M Shapes:1
# Iteration 1226 Number of M Shapes:2
# Iteration 1227 Number of M Shapes:4
# Iteration 1228 Number of M Shapes:3
# Iteration 1229 Number of M Shapes:3
# Iteration 1230 Number of M Shapes:2
# Iteration 1231 Number of M Shapes:3
# Iteration 1232 Number of M Shapes:4
# Iteration 1233 Number of M Shapes:3
# Iteration 1234 Number of M Shapes:4
# Iteration 1235 Number of M Shapes:4
# Iteration 1236 Number of M Shapes:3
# Iteration 1237 Number of M Shapes:2
# Iteration 1238 Number of M Shapes:3
# Iteration 1239 Number of M Shapes:3
# Iteration 1240 Number of M Shapes:3
# Iteration 1241 Number of M Shapes:3
# Iteration 1242 Number of M Shapes:3
# Iteration 1243 Number of M Shapes:2
# Iteration 1244 Number of M Shapes:1
# Iteration 1245 Number of M Shapes:1
# Iteration 1246 Number of M Shapes:2
# Iteration 1247 Number of M Shapes:1
# Iteration 1248 Number of M Shapes:2
# Iteration 1249 Number of M Shapes:1
# Iteration 1250 Number of M Shapes:3
# Iteration 1251 Number of M Shapes:2
# Iteration 1252 Number of M Shapes:1
# Iteration 1253 Number of M Shapes:1
# Iteration 1254 Number of M Shapes:3
# Iteration 1255 Number of M Shapes:1
# Iteration 1256 Number of M Shapes:1
# Iteration 1257 Number of M Shapes:1
# Iteration 1258 Number of M Shapes:3
# Iteration 1259 Number of M Shapes:3
# Iteration 1260 Number of M Shapes:1
# Iteration 1261 Number of M Shapes:3
# Iteration 1262 Number of M Shapes:3
# Iteration 1263 Number of M Shapes:1
# Iteration 1264 Number of M Shapes:1
# Iteration 1265 Number of M Shapes:4
# Iteration 1266 Number of M Shapes:2
# Iteration 1267 Number of M Shapes:3
# Iteration 1268 Number of M Shapes:1
# Iteration 1269 Number of M Shapes:4
# Iteration 1270 Number of M Shapes:2
# Iteration 1271 Number of M Shapes:2
# Iteration 1272 Number of M Shapes:2
# Iteration 1273 Number of M Shapes:1
# Iteration 1274 Number of M Shapes:2
# Iteration 1275 Number of M Shapes:1
# Iteration 1276 Number of M Shapes:2
# Iteration 1277 Number of M Shapes:4
# Iteration 1278 Number of M Shapes:1
# Iteration 1279 Number of M Shapes:2
# Iteration 1280 Number of M Shapes:4
# Iteration 1281 Number of M Shapes:1
# Iteration 1282 Number of M Shapes:1
# Iteration 1283 Number of M Shapes:3
# Iteration 1284 Number of M Shapes:3
# Iteration 1285 Number of M Shapes:1
# Iteration 1286 Number of M Shapes:3
# Iteration 1287 Number of M Shapes:3
# Iteration 1288 Number of M Shapes:1
# Iteration 1289 Number of M Shapes:4
# Iteration 1290 Number of M Shapes:2
# Iteration 1291 Number of M Shapes:2
# Iteration 1292 Number of M Shapes:3
# Iteration 1293 Number of M Shapes:3
# Iteration 1294 Number of M Shapes:2
# Iteration 1295 Number of M Shapes:1
# Iteration 1296 Number of M Shapes:3
# Iteration 1297 Number of M Shapes:3
# Iteration 1298 Number of M Shapes:3
# Iteration 1299 Number of M Shapes:2
# Iteration 1300 Number of M Shapes:3
# Iteration 1301 Number of M Shapes:2
# Iteration 1302 Number of M Shapes:1
# Iteration 1303 Number of M Shapes:2
# Iteration 1304 Number of M Shapes:1
# Iteration 1305 Number of M Shapes:3
# Iteration 1306 Number of M Shapes:1
# Iteration 1307 Number of M Shapes:2
# Iteration 1308 Number of M Shapes:2
# Iteration 1309 Number of M Shapes:3
# Iteration 1310 Number of M Shapes:2
# Iteration 1311 Number of M Shapes:2
# Iteration 1312 Number of M Shapes:2
# Iteration 1313 Number of M Shapes:2
# Iteration 1314 Number of M Shapes:1
# Iteration 1315 Number of M Shapes:4
# Iteration 1316 Number of M Shapes:3
# Iteration 1317 Number of M Shapes:2
# Iteration 1318 Number of M Shapes:1
# Iteration 1319 Number of M Shapes:3
# Iteration 1320 Number of M Shapes:2
# Iteration 1321 Number of M Shapes:1
# Iteration 1322 Number of M Shapes:3
# Iteration 1323 Number of M Shapes:1
# Iteration 1324 Number of M Shapes:4
# Iteration 1325 Number of M Shapes:4
# Iteration 1326 Number of M Shapes:2
# Iteration 1327 Number of M Shapes:2
# Iteration 1328 Number of M Shapes:4
# Iteration 1329 Number of M Shapes:2
# Iteration 1330 Number of M Shapes:3
# Iteration 1331 Number of M Shapes:1
# Iteration 1332 Number of M Shapes:2
# Iteration 1333 Number of M Shapes:2
# Iteration 1334 Number of M Shapes:1
# Iteration 1335 Number of M Shapes:1
# Iteration 1336 Number of M Shapes:1
# Iteration 1337 Number of M Shapes:1
# Iteration 1338 Number of M Shapes:2
# Iteration 1339 Number of M Shapes:1
# ...
# Iteration 4685 Number of M Shapes:2
# Iteration 4686 Number of M Shapes:3
# Iteration 4687 Number of M Shapes:2
# Iteration 4688 Number of M Shapes:3
# Iteration 4689 Number of M Shapes:1
# Iteration 4690 Number of M Shapes:2
# Iteration 4691 Number of M Shapes:2
# Iteration 4692 Number of M Shapes:1
# Iteration 4693 Number of M Shapes:4
# Iteration 4694 Number of M Shapes:3
# Iteration 4695 Number of M Shapes:3
# Iteration 4696 Number of M Shapes:3
# Iteration 4697 Number of M Shapes:2
# Iteration 4698 Number of M Shapes:1
# Iteration 4699 Number of M Shapes:3
# Iteration 4700 Number of M Shapes:1
# Iteration 4701 Number of M Shapes:4
# Iteration 4702 Number of M Shapes:3
# Iteration 4703 Number of M Shapes:3
# Iteration 4704 Number of M Shapes:1
# Iteration 4705 Number of M Shapes:3
# Iteration 4706 Number of M Shapes:3
# Iteration 4707 Number of M Shapes:1
# Iteration 4708 Number of M Shapes:3
# Iteration 4709 Number of M Shapes:3
# Iteration 4710 Number of M Shapes:4
# Iteration 4711 Number of M Shapes:3
# Iteration 4712 Number of M Shapes:4
# Iteration 4713 Number of M Shapes:1
# Iteration 4714 Number of M Shapes:2
# Iteration 4715 Number of M Shapes:2
# Iteration 4716 Number of M Shapes:3
# Iteration 4717 Number of M Shapes:2
# Iteration 4718 Number of M Shapes:3
# Iteration 4719 Number of M Shapes:2
# Iteration 4720 Number of M Shapes:2
# Iteration 4721 Number of M Shapes:4
# Iteration 4722 Number of M Shapes:2
# Iteration 4723 Number of M Shapes:2
# Iteration 4724 Number of M Shapes:1
# Iteration 4725 Number of M Shapes:3
# Iteration 4726 Number of M Shapes:2
# Iteration 4727 Number of M Shapes:4
# Iteration 4728 Number of M Shapes:3
# Iteration 4729 Number of M Shapes:1
# Iteration 4730 Number of M Shapes:1
# Iteration 4731 Number of M Shapes:1
# Iteration 4732 Number of M Shapes:2
# Iteration 4733 Number of M Shapes:2
# Iteration 4734 Number of M Shapes:3
# Iteration 4735 Number of M Shapes:4
# Iteration 4736 Number of M Shapes:2
# Iteration 4737 Number of M Shapes:3
# Iteration 4738 Number of M Shapes:2
# Iteration 4739 Number of M Shapes:3
# Iteration 4740 Number of M Shapes:3
# Iteration 4741 Number of M Shapes:3
# Iteration 4742 Number of M Shapes:3
# Iteration 4743 Number of M Shapes:2
# Iteration 4744 Number of M Shapes:2
# Iteration 4745 Number of M Shapes:1
# Iteration 4746 Number of M Shapes:3
# Iteration 4747 Number of M Shapes:2
# Iteration 4748 Number of M Shapes:1
# Iteration 4749 Number of M Shapes:4
# Iteration 4750 Number of M Shapes:5
# Iteration 4751 Number of M Shapes:2
# Iteration 4752 Number of M Shapes:2
# Iteration 4753 Number of M Shapes:3
# Iteration 4754 Number of M Shapes:1
# Iteration 4755 Number of M Shapes:1
# Iteration 4756 Number of M Shapes:3
# Iteration 4757 Number of M Shapes:1
# Iteration 4758 Number of M Shapes:4
# Iteration 4759 Number of M Shapes:3
# Iteration 4760 Number of M Shapes:3
# Iteration 4761 Number of M Shapes:2
# Iteration 4762 Number of M Shapes:3
# Iteration 4763 Number of M Shapes:5
# Iteration 4764 Number of M Shapes:1
# Iteration 4765 Number of M Shapes:2
# Iteration 4766 Number of M Shapes:3
# Iteration 4767 Number of M Shapes:2
# Iteration 4768 Number of M Shapes:1
# Iteration 4769 Number of M Shapes:3
# Iteration 4770 Number of M Shapes:2
# Iteration 4771 Number of M Shapes:3
# Iteration 4772 Number of M Shapes:2
# Iteration 4773 Number of M Shapes:4
# Iteration 4774 Number of M Shapes:1
# Iteration 4775 Number of M Shapes:4
# Iteration 4776 Number of M Shapes:1
# Iteration 4777 Number of M Shapes:2
# Iteration 4778 Number of M Shapes:3
# Iteration 4779 Number of M Shapes:2
# Iteration 4780 Number of M Shapes:1
# Iteration 4781 Number of M Shapes:1
# Iteration 4782 Number of M Shapes:3
# Iteration 4783 Number of M Shapes:3
# Iteration 4784 Number of M Shapes:3
# Iteration 4785 Number of M Shapes:5
# Iteration 4786 Number of M Shapes:4
# Iteration 4787 Number of M Shapes:1
# Iteration 4788 Number of M Shapes:2
# Iteration 4789 Number of M Shapes:1
# Iteration 4790 Number of M Shapes:1
# Iteration 4791 Number of M Shapes:1
# Iteration 4792 Number of M Shapes:3
# Iteration 4793 Number of M Shapes:3
# Iteration 4794 Number of M Shapes:1
# Iteration 4795 Number of M Shapes:2
# Iteration 4796 Number of M Shapes:3
# Iteration 4797 Number of M Shapes:2
# Iteration 4798 Number of M Shapes:1
# Iteration 4799 Number of M Shapes:2
# Iteration 4800 Number of M Shapes:1
# Iteration 4801 Number of M Shapes:1
# Iteration 4802 Number of M Shapes:3
# Iteration 4803 Number of M Shapes:1
# Iteration 4804 Number of M Shapes:3
# Iteration 4805 Number of M Shapes:1
# Iteration 4806 Number of M Shapes:1
# Iteration 4807 Number of M Shapes:1
# Iteration 4808 Number of M Shapes:2
# Iteration 4809 Number of M Shapes:4
# Iteration 4810 Number of M Shapes:4
# Iteration 4811 Number of M Shapes:2
# Iteration 4812 Number of M Shapes:2
# Iteration 4813 Number of M Shapes:1
# Iteration 4814 Number of M Shapes:4
# Iteration 4815 Number of M Shapes:3
# Iteration 4816 Number of M Shapes:3
# Iteration 4817 Number of M Shapes:4
# Iteration 4818 Number of M Shapes:2
# Iteration 4819 Number of M Shapes:3
# Iteration 4820 Number of M Shapes:4
# Iteration 4821 Number of M Shapes:3
# Iteration 4822 Number of M Shapes:2
# Iteration 4823 Number of M Shapes:2
# Iteration 4824 Number of M Shapes:4
# Iteration 4825 Number of M Shapes:1
# Iteration 4826 Number of M Shapes:3
# Iteration 4827 Number of M Shapes:4
# Iteration 4828 Number of M Shapes:3
# Iteration 4829 Number of M Shapes:2
# Iteration 4830 Number of M Shapes:4
# Iteration 4831 Number of M Shapes:2
# Iteration 4832 Number of M Shapes:3
# Iteration 4833 Number of M Shapes:2
# Iteration 4834 Number of M Shapes:1
# Iteration 4835 Number of M Shapes:3
# Iteration 4836 Number of M Shapes:2
# Iteration 4837 Number of M Shapes:1
# Iteration 4838 Number of M Shapes:4
# Iteration 4839 Number of M Shapes:4
# Iteration 4840 Number of M Shapes:3
# Iteration 4841 Number of M Shapes:2
# Iteration 4842 Number of M Shapes:4
# Iteration 4843 Number of M Shapes:2
# Iteration 4844 Number of M Shapes:1
# Iteration 4845 Number of M Shapes:2
# Iteration 4846 Number of M Shapes:1
# Iteration 4847 Number of M Shapes:1
# Iteration 4848 Number of M Shapes:3
# Iteration 4849 Number of M Shapes:4
# Iteration 4850 Number of M Shapes:4
# Iteration 4851 Number of M Shapes:2
# Iteration 4852 Number of M Shapes:3
# Iteration 4853 Number of M Shapes:2
# Iteration 4854 Number of M Shapes:3
# Iteration 4855 Number of M Shapes:3
# Iteration 4856 Number of M Shapes:2
# Iteration 4857 Number of M Shapes:3
# Iteration 4858 Number of M Shapes:2
# Iteration 4859 Number of M Shapes:1
# Iteration 4860 Number of M Shapes:2
# Iteration 4861 Number of M Shapes:3
# Iteration 4862 Number of M Shapes:3
# Iteration 4863 Number of M Shapes:2
# Iteration 4864 Number of M Shapes:3
# Iteration 4865 Number of M Shapes:4
# Iteration 4866 Number of M Shapes:1
# Iteration 4867 Number of M Shapes:3
# Iteration 4868 Number of M Shapes:2
# Iteration 4869 Number of M Shapes:2
# Iteration 4870 Number of M Shapes:1
# Iteration 4871 Number of M Shapes:1
# Iteration 4872 Number of M Shapes:4
# Iteration 4873 Number of M Shapes:2
# Iteration 4874 Number of M Shapes:4
# Iteration 4875 Number of M Shapes:3
# Iteration 4876 Number of M Shapes:2
# Iteration 4877 Number of M Shapes:3
# Iteration 4878 Number of M Shapes:3
# Iteration 4879 Number of M Shapes:3
# Iteration 4880 Number of M Shapes:3
# Iteration 4881 Number of M Shapes:4
# Iteration 4882 Number of M Shapes:2
# Iteration 4883 Number of M Shapes:3
# Iteration 4884 Number of M Shapes:3
# Iteration 4885 Number of M Shapes:1
# Iteration 4886 Number of M Shapes:1
# Iteration 4887 Number of M Shapes:4
# Iteration 4888 Number of M Shapes:1
# Iteration 4889 Number of M Shapes:2
# Iteration 4890 Number of M Shapes:2
# Iteration 4891 Number of M Shapes:4
# Iteration 4892 Number of M Shapes:3
# Iteration 4893 Number of M Shapes:3
# Iteration 4894 Number of M Shapes:3
# Iteration 4895 Number of M Shapes:2
# Iteration 4896 Number of M Shapes:3
# Iteration 4897 Number of M Shapes:3
# Iteration 4898 Number of M Shapes:3
# Iteration 4899 Number of M Shapes:1
# Iteration 4900 Number of M Shapes:1
# Iteration 4901 Number of M Shapes:1
# Iteration 4902 Number of M Shapes:4
# Iteration 4903 Number of M Shapes:4
# Iteration 4904 Number of M Shapes:1
# Iteration 4905 Number of M Shapes:1
# Iteration 4906 Number of M Shapes:1
# Iteration 4907 Number of M Shapes:2
# Iteration 4908 Number of M Shapes:4
# Iteration 4909 Number of M Shapes:3
# Iteration 4910 Number of M Shapes:1
# Iteration 4911 Number of M Shapes:4
# Iteration 4912 Number of M Shapes:3
# Iteration 4913 Number of M Shapes:1
# Iteration 4914 Number of M Shapes:2
# Iteration 4915 Number of M Shapes:3
# Iteration 4916 Number of M Shapes:2
# Iteration 4917 Number of M Shapes:2
# Iteration 4918 Number of M Shapes:2
# Iteration 4919 Number of M Shapes:3
# Iteration 4920 Number of M Shapes:3
# Iteration 4921 Number of M Shapes:1
# Iteration 4922 Number of M Shapes:3
# Iteration 4923 Number of M Shapes:1
# Iteration 4924 Number of M Shapes:2
# Iteration 4925 Number of M Shapes:3
# Iteration 4926 Number of M Shapes:2
# Iteration 4927 Number of M Shapes:2
# Iteration 4928 Number of M Shapes:3
# Iteration 4929 Number of M Shapes:2
# Iteration 4930 Number of M Shapes:3
# Iteration 4931 Number of M Shapes:3
# Iteration 4932 Number of M Shapes:4
# Iteration 4933 Number of M Shapes:2
# Iteration 4934 Number of M Shapes:3
# Iteration 4935 Number of M Shapes:2
# Iteration 4936 Number of M Shapes:4
# Iteration 4937 Number of M Shapes:2
# Iteration 4938 Number of M Shapes:1
# Iteration 4939 Number of M Shapes:2
# Iteration 4940 Number of M Shapes:3
# Iteration 4941 Number of M Shapes:2
# Iteration 4942 Number of M Shapes:2
# Iteration 4943 Number of M Shapes:4
# Iteration 4944 Number of M Shapes:1
# Iteration 4945 Number of M Shapes:2
# Iteration 4946 Number of M Shapes:2
# Iteration 4947 Number of M Shapes:3
# Iteration 4948 Number of M Shapes:4
# Iteration 4949 Number of M Shapes:2
# Iteration 4950 Number of M Shapes:3
# Iteration 4951 Number of M Shapes:3
# Iteration 4952 Number of M Shapes:2
# Iteration 4953 Number of M Shapes:1
# Iteration 4954 Number of M Shapes:4
# Iteration 4955 Number of M Shapes:3
# Iteration 4956 Number of M Shapes:2
# Iteration 4957 Number of M Shapes:2
# Iteration 4958 Number of M Shapes:3
# Iteration 4959 Number of M Shapes:3
# Iteration 4960 Number of M Shapes:2
# Iteration 4961 Number of M Shapes:1
# Iteration 4962 Number of M Shapes:1
# Iteration 4963 Number of M Shapes:1
# Iteration 4964 Number of M Shapes:2
# Iteration 4965 Number of M Shapes:3
# Iteration 4966 Number of M Shapes:2
# Iteration 4967 Number of M Shapes:2
# Iteration 4968 Number of M Shapes:1
# Iteration 4969 Number of M Shapes:3
# Iteration 4970 Number of M Shapes:2
# Iteration 4971 Number of M Shapes:3
# Iteration 4972 Number of M Shapes:4
# Iteration 4973 Number of M Shapes:1
# Iteration 4974 Number of M Shapes:4
# Iteration 4975 Number of M Shapes:1
# Iteration 4976 Number of M Shapes:3
# Iteration 4977 Number of M Shapes:2
# Iteration 4978 Number of M Shapes:2
# Iteration 4979 Number of M Shapes:1
# Iteration 4980 Number of M Shapes:2
# Iteration 4981 Number of M Shapes:3
# Iteration 4982 Number of M Shapes:1
# Iteration 4983 Number of M Shapes:4
# Iteration 4984 Number of M Shapes:1
# Iteration 4985 Number of M Shapes:1
# Iteration 4986 Number of M Shapes:4
# Iteration 4987 Number of M Shapes:3
# Iteration 4988 Number of M Shapes:3
# Iteration 4989 Number of M Shapes:1
# Iteration 4990 Number of M Shapes:2
# Iteration 4991 Number of M Shapes:2
# Iteration 4992 Number of M Shapes:1
# Iteration 4993 Number of M Shapes:2
# Iteration 4994 Number of M Shapes:3
# Iteration 4995 Number of M Shapes:2
# Iteration 4996 Number of M Shapes:1
# Iteration 4997 Number of M Shapes:4
# Iteration 4998 Number of M Shapes:3
# Iteration 4999 Number of M Shapes:1
# Spheres: 1
# Cones: 1
# Sphere 0:
# X: 2.0, Y: 2.0, Z: 1.0, Radius: 3
# Cone 0:
# X: 0.0, Y: 0.0, Z: 2.0, Radius: 3, Height: 3, Tip X: -0.6949318205978102, Tip Y: 0.7548971921296381, Tip Z: 4.819077862357725
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7026027a-82ca-4ee3-ba78-c465ddd0b077" class="plotly-graph-div" style="height:1000px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7026027a-82ca-4ee3-ba78-c465ddd0b077")) {                    Plotly.newPlot(                        "7026027a-82ca-4ee3-ba78-c465ddd0b077",                        [{"colorscale":[[0.0,"green"],[1.0,"green"]],"opacity":0.3,"x":[[2.0,3.026060429977006,3.9283628290596178,4.598076211353316,4.9544232590366235,4.9544232590366235,4.598076211353316,3.928362829059618,3.0260604299770066,2.0000000000000004],[2.0,2.970465645699019,3.8238788119792,4.457305275950228,4.7943444576782195,4.7943444576782195,4.457305275950229,3.823878811979201,2.9704656456990195,2.0000000000000004],[2.0,2.809705850383537,3.5217492252251774,4.050247184878008,4.331455075608714,4.331455075608714,4.050247184878009,3.521749225225178,2.8097058503835375,2.0000000000000004],[2.0,2.561201862298229,3.0547144975459104,3.4210129984613893,3.6159163598441397,3.6159163598441397,3.4210129984613893,3.054714497545911,2.5612018622982293,2.0],[2.0,2.2518829444888033,2.47338508847591,2.6377900043729907,2.7252680329647134,2.7252680329647134,2.6377900043729907,2.47338508847591,2.2518829444888033,2.0],[2.0,1.915268601277439,1.8407570597430818,1.7854525669792063,1.7560256610205207,1.7560256610205207,1.7854525669792063,1.8407570597430818,1.915268601277439,2.0],[2.0,1.5878362198607783,1.2253854744958956,0.9563646729996524,0.8132216943566739,0.8132216943566739,0.9563646729996522,1.2253854744958956,1.587836219860778,1.9999999999999998],[2.0,1.3050681794021899,0.6939553924698421,0.2403708603711756,-0.0009764281279682763,-0.0009764281279682763,0.2403708603711754,0.6939553924698416,1.3050681794021894,1.9999999999999998],[2.0,1.0976067846835793,0.3040555090397805,-0.2849398315192433,-0.5983377062766402,-0.5983377062766402,-0.28493983151924374,0.30405550903977985,1.0976067846835789,1.9999999999999998],[2.0,0.9879336969179224,0.09793752649539433,-0.5626418381700633,-0.9141287765866832,-0.9141287765866832,-0.5626418381700637,0.09793752649539367,0.987933696917922,1.9999999999999996],[2.0,0.9879336969179224,0.09793752649539433,-0.5626418381700633,-0.9141287765866832,-0.9141287765866832,-0.5626418381700637,0.09793752649539367,0.987933696917922,1.9999999999999996],[2.0,1.0976067846835793,0.3040555090397803,-0.28493983151924374,-0.5983377062766406,-0.5983377062766406,-0.2849398315192442,0.3040555090397796,1.0976067846835789,1.9999999999999998],[2.0,1.3050681794021892,0.693955392469841,0.24037086037117406,-0.0009764281279700526,-0.0009764281279700526,0.24037086037117383,0.6939553924698405,1.305068179402189,1.9999999999999998],[2.0,1.5878362198607776,1.2253854744958945,0.9563646729996507,0.8132216943566721,0.8132216943566721,0.9563646729996504,1.2253854744958943,1.5878362198607774,1.9999999999999998],[2.0,1.9152686012774385,1.840757059743081,1.7854525669792052,1.7560256610205194,1.7560256610205194,1.7854525669792052,1.840757059743081,1.9152686012774385,2.0],[2.0,2.251882944488803,2.473385088475909,2.63779000437299,2.725268032964712,2.725268032964712,2.63779000437299,2.473385088475909,2.251882944488803,2.0],[2.0,2.5612018622982284,3.0547144975459095,3.4210129984613884,3.615916359844138,3.615916359844138,3.4210129984613884,3.05471449754591,2.561201862298229,2.0],[2.0,2.809705850383537,3.521749225225177,4.050247184878007,4.331455075608714,4.331455075608714,4.050247184878008,3.521749225225178,2.8097058503835375,2.0000000000000004],[2.0,2.970465645699019,3.8238788119792,4.457305275950228,4.7943444576782195,4.7943444576782195,4.457305275950229,3.823878811979201,2.9704656456990195,2.0000000000000004],[2.0,3.026060429977006,3.9283628290596178,4.598076211353316,4.9544232590366235,4.9544232590366235,4.598076211353316,3 ...
